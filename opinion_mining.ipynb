# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import nltk
import re 
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, sentiwordnet

nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df = pd.read_excel('/content/dataset.xlsx')
df.head()
# Out:
#    Unnamed: 0                                            content product  year
# 0           0  So here's my survival story: received the prod...  Chaoba  2019
# 1           1  Its been just two months,, i have used 3 to 4 ...  Chaoba  2018
# 2           2  Product working good. Heat protection is activ...  Chaoba  2019
# 3           3  "Hair style with safety - This is what I was l...  Chaoba  2018
# 4           4  The motor of the drier gave up in just 3rd use...  Chaoba  2018

# %%
df.drop(columns=['Unnamed: 0'])
# Out:
#                                                  content         product  year
# 0      So here's my survival story: received the prod...          Chaoba  2019
# 1      Its been just two months,, i have used 3 to 4 ...          Chaoba  2018
# 2      Product working good. Heat protection is activ...          Chaoba  2019
# 3      "Hair style with safety - This is what I was l...          Chaoba  2018
# 4      The motor of the drier gave up in just 3rd use...          Chaoba  2018
# ...                                                  ...             ...   ...
# 18263                                      It's awesome.  Philips_HP8100  2021
# 18264                                          Very good  Philips_HP8100  2018
# 18265  It's a bit noisy, but can't really complain at...  Philips_HP8100  2018
# 18266                                            Awesome  Philips_HP8100  2019
# 18267                                It's a good product  Philips_HP8100  2018
#
# [18268 rows x 3 columns]

# %%
df['word_count'] = df['content'].apply(lambda x: len(str(x).split(" ")))
ds_count = len(df.word_count)

# %%
corpus = []
for i in range(0, ds_count):
  # remove punctuation
  text = re.sub('[^a-zA-Z]', ' ', str(df['content'][i]))

  # convert to lowercase
  text = text.lower()

  # Remove tags
  text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)
  
  # Remove special characters and digits
  text=re.sub("(\\d|\\W)+"," ",text)
  
  # Convert to list from string
  text = text.split()
  
  text = " ".join(text)
  corpus.append(text)

# %%
len(corpus)
# Out:
# 18268

# %%
tagged_corpus = []
for sen in corpus:
  text = word_tokenize(sen)
  text = nltk.pos_tag(text)
  tagged_corpus.append(text)

# %%
tagged_corpus[:1]
# Out:
# [[('so', 'RB'),
#   ('here', 'RB'),
#   ('s', 'JJ'),
#   ('my', 'PRP$'),
#   ('survival', 'JJ'),
#   ('story', 'NN'),
#   ('received', 'VBD'),
#   ('the', 'DT'),
#   ('product', 'NN'),
#   ('without', 'IN'),
#   ('any', 'DT'),
#   ('protection', 'NN'),
#   ('as', 'RB'),
#   ('soon', 'RB'),
#   ('as', 'IN'),
#   ('i', 'NN'),
#   ('plugged', 'VBD'),
#   ('it', 'PRP'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('socket', 'NN'),
#   ('and', 'CC'),
#   ('turned', 'VBD'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('electricity', 'NN'),
#   ('button', 'NN'),
#   ('without', 'IN'),
#   ('even', 'RB'),
#   ('toggling', 'VBG'),
#   ('the', 'DT'),
#   ('hairdryer', 'NN'),
#   ('s', 'NN'),
#   ('buttons', 'NNS'),
#   ('it', 'PRP'),
#   ('started', 'VBD'),
#   ('giving', 'VBG'),
#   ('smoke', 'NN'),
#   ('it', 'PRP'),
#   ('s', 'VBZ'),
#   ('mouth', 'JJ'),
#   ('become', 'JJ'),
#   ('red', 'JJ'),
#   ('hot', 'JJ'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('smoke', 'NN'),
#   ('intensified', 'VBD'),
#   ('within', 'IN'),
#   ('seconds', 'NNS'),
#   ('it', 'PRP'),
#   ('started', 'VBD'),
#   ('burning', 'VBG'),
#   ('with', 'IN'),
#   ('flames', 'NNS'),
#   ('we', 'PRP'),
#   ('got', 'VBD'),
#   ('very', 'RB'),
#   ('frightened', 'JJ'),
#   ('and', 'CC'),
#   ('immediately', 'RB'),
#   ('extingued', 'VBD'),
#   ('the', 'DT'),
#   ('fire', 'NN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('very', 'RB'),
#   ('dangerous', 'JJ'),
#   ('machine', 'NN'),
#   ('it', 'PRP'),
#   ('can', 'MD'),
#   ('harm', 'VB'),
#   ('you', 'PRP'),
#   ('or', 'CC'),
#   ('your', 'PRP$'),
#   ('dear', 'JJ'),
#   ('ones', 'NNS'),
#   ('please', 'VB'),
#   ('do', 'VBP'),
#   ('not', 'RB'),
#   ('purchase', 'VB'),
#   ('please', 'NN'),
#   ('check', 'VB'),
#   ('the', 'DT'),
#   ('attached', 'JJ'),
#   ('photos', 'NN')]]

# %%
chunkGram = r"""Chunk: {<RB.?>*<VB.?>*<NNP>+<NN>?}"""
chunkParser = nltk.RegexpParser(chunkGram)
chunked = chunkParser.parse(tagged_corpus)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-037d844214b7> in <module>()
#       1 chunkGram = r"""Chunk: {<RB.?>*<VB.?>*<NNP>+<NN>?}"""
#       2 chunkParser = nltk.RegexpParser(chunkGram)
# ----> 3 chunked = chunkParser.parse(tagged_corpus)
#
# /usr/local/lib/python3.7/dist-packages/nltk/chunk/regexp.py in parse(self, chunk_struct, trace)
#    1206         for i in range(self._loop):
#    1207             for parser in self._stages:
# -> 1208                 chunk_struct = parser.parse(chunk_struct, trace=trace)
#    1209         return chunk_struct
#    1210
#
# /usr/local/lib/python3.7/dist-packages/nltk/chunk/regexp.py in parse(self, chunk_struct, trace)
#    1021         if trace is None: trace = self._trace
#    1022
# -> 1023         chunkstr = ChunkString(chunk_struct)
#    1024
#    1025         # Apply the sequence of rules to the chunkstring.
#
# /usr/local/lib/python3.7/dist-packages/nltk/chunk/regexp.py in __init__(self, chunk_struct, debug_level)
#      95         self._root_label = chunk_struct.label()
#      96         self._pieces = chunk_struct[:]
# ---> 97         tags = [self._tag(tok) for tok in self._pieces]
#      98         self._str = '<' + '><'.join(tags) + '>'
#      99         self._debug = debug_level
#
# /usr/local/lib/python3.7/dist-packages/nltk/chunk/regexp.py in <listcomp>(.0)
#      95         self._root_label = chunk_struct.label()
#      96         self._pieces = chunk_struct[:]
# ---> 97         tags = [self._tag(tok) for tok in self._pieces]
#      98         self._str = '<' + '><'.join(tags) + '>'
#      99         self._debug = debug_level
#
# /usr/local/lib/python3.7/dist-packages/nltk/chunk/regexp.py in _tag(self, tok)
#     105             return tok.label()
#     106         else:
# --> 107             raise ValueError('chunk structures must contain tagged '
#     108                              'tokens or trees')
#     109
#
# ValueError: chunk structures must contain tagged tokens or trees
