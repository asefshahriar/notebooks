# %%
import numpy as np
import pandas as pd

# %%
l = [8, 10, 12, 16, 18]
number_sample = 60

# %% [markdown]
# # New section

# %%
sample = pd.DataFrame(np.random.choice(l, size=60))
sample
# Out:
#      0
# 0   18
# 1   18
# 2   10
# 3   16
# 4   16
# 5   12
# 6    8
# 7   16
# 8   18
# 9   12
# 10  18
# 11  12
# 12  16
# 13   8
# 14  16
# 15   8
# 16   8
# 17  12
# 18  16
# 19  12
# 20  18
# 21  12
# 22  12
# 23  18
# 24  18
# 25  16
# 26  12
# 27   8
# 28   8
# 29  16
# 30  16
# 31  12
# 32   8
# 33  12
# 34  12
# 35  18
# 36  12
# 37  12
# 38  16
# 39   8
# 40  16
# 41  18
# 42  18
# 43  10
# 44  10
# 45  10
# 46  10
# 47  18
# 48  16
# 49  16
# 50   8
# 51   8
# 52  10
# 53  16
# 54  10
# 55  12
# 56  12
# 57   8
# 58   8
# 59  10

# %%
sample.to_excel('sample.xlsx')
