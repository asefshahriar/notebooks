# %%
# !pip install upsetplot
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for upsetplot: filename=UpSetPlot-0.9.0-py3-none-any.whl size=24816 sha256=6d1987eabacb79711d56d04b34537ee691474c0ee4618bbabc8bfa53508d6297
#   Stored in directory: /root/.cache/pip/wheels/73/42/9f/1c9718ea27f30466d2787e0f7d88a7cb11942e3460c17e0ef6
# Successfully built upsetplot
# ...

# %%
from upsetplot import from_memberships
job_sector = from_memberships(
    [['Banking and Finance'],
     ['Development'],
     ['Education'],
     ['Education', 'Development'],
     ['Education', 'Research'],
     ['Healthcare'],
     ['Humanitarian and \nHuman Rights'],
     ['Private and Retail'],
     ['Research'],
     ['Research', 'Development'],
     ['Research', 'Healthcare'],
     ['Student or Unemployed'],
     ['Unknown']
     ],
     data=[1.33, 9.33, 16.67, 1.33, 5.33, 1.33, 16.0, 15.33, 1.33, 1.33, 2.0, 24.67, 4.0]
)

# %%
# Plot the upset plot
# upset = UpSet(job_sector, show_counts=True, facecolor="darkblue")
upset = UpSet(job_sector, facecolor="darkblue")
# plt.figure(figsize=(15, 6))  # Adjust the figure size as needed
upset.plot()
plt.suptitle('Job Sectors')  # Add title to the plot

# Save the plot in high resolution (300 dpi)
plt.savefig('job_sectors_upset_plot.png', dpi=600)

# Display the plot
plt.show()
