# %%
# !pip install keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.1.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 13.5 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (2.23.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (2.8.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (5.5.0)
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.4-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (1.21.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (21.3)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (5.1.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (4.8.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (0.8.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (4.4.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (1.0.18)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (57.4.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->keras-tuner) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->keras-tuner) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->keras-tuner) (3.0.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->keras-tuner) (0.7.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner) (2.10)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.35.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (0.6.1)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (3.17.3)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.44.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (3.3.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard->keras-tuner) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras-tuner) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras-tuner) (3.10.0.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->keras-tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner) (3.2.0)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.1.2 kt-legacy-1.0.4

# %%
# Commented out IPython magic to ensure Python compatibility.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import datetime as dt
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv1D, MaxPooling1D, AveragePooling1D , Flatten, Input, LSTM
from sklearn.model_selection import train_test_split
import pprint as pp
import keras_tuner as kt
from tensorflow.keras.utils import plot_model
from sklearn.utils import shuffle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel("/content/drive/MyDrive/dataset.xlsx")
df.plot(x = 'date', y = 'sales')
plt.show()

# %%
raw_seq = df['sales']

# %%
train_seq = raw_seq[:1095]
val_seq = raw_seq[1095:1461].reset_index(drop=True)
test_seq = raw_seq[1461:].reset_index(drop=True)

# %%
print(train_seq.size, val_seq.size, test_seq.size)
# Out:
# 1095 366 365

# %%
# univariate data preparation
# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
  X, y = list(), list()
  for i in range(len(sequence)):
    # find the end of this pattern
    end_ix = i + n_steps
    # check if we are beyond the sequence
    if end_ix > len(sequence)-1:
      break
    # gather input and output parts of the pattern
    seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
    X.append(seq_x)
    y.append(seq_y)
  return np.array(X), np.array(y)

# %%
n_steps = 30
n_features = 1
X_train, y_train = split_sequence(train_seq, n_steps)
X_train_shuffled, y_train_shuffled = shuffle(X_train, y_train, random_state=10)
X_test, y_test = split_sequence(test_seq, n_steps)
X_val, y_val = split_sequence(val_seq, n_steps)

X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], n_features))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], n_features))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], n_features))

# %%
def stacked_LSTM(hp):
    model = tf.keras.Sequential()
    model.add(Input(shape=(30, 1)))

    for i in range(hp.Int('num_layers', min_value=2, max_value=20, step=1)):
      model.add(LSTM(units=hp.Int('units' + str(i), min_value=32, max_value=512, step=32), activation='tanh', recurrent_activation='sigmoid', return_sequences=True))
      model.add(Dropout(hp.Float('dropout' + str(i), 0, 0.5, step=0.1, default=0)))
    model.add(Flatten())
    model.add(Dense(1))
    
    
    model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError(), tf.keras.metrics.MeanSquaredError()])

    return model

# %%
tuner = kt.tuners.Hyperband(
    stacked_LSTM,
    objective='val_mean_squared_error',
    max_epochs=30,
    hyperband_iterations=5,
    directory='stacked_lstm_exp',
    project_name='demand forecasting')

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 5
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 20, 'step': 1, 'sampling': None}
# units0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# dropout0 (Float)
# {'default': 0, 'conditions': [], 'min_value': 0.0, 'max_value': 0.5, 'step': 0.1, 'sampling': None}
# units1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# dropout1 (Float)
# {'default': 0, 'conditions': [], 'min_value': 0.0, 'max_value': 0.5, 'step': 0.1, 'sampling': None}

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)

# %%
tuner.search(X_train_shuffled, y_train_shuffled, epochs=50, validation_data=(X_val, y_val), callbacks=[stop_early])
# Out:
# Trial 21 Complete [00h 02m 41s]
# val_mean_squared_error: 48.78153610229492
#
# Best val_mean_squared_error So Far: 34.25746536254883
# Total elapsed time: 00h 47m 57s
#
# Search: Running Trial #22
#
# Value             |Best Value So Far |Hyperparameter
# 11                |2                 |num_layers
# 448               |256               |units0
# 0.2               |0.1               |dropout0
# 288               |320               |units1
# 0.3               |0.2               |dropout1
# 64                |32                |units2
# 0.2               |0.3               |dropout2
# 256               |480               |units3
# 0.5               |0.4               |dropout3
# 256               |96                |units4
# 0.2               |0.1               |dropout4
# 416               |96                |units5
# 0.2               |0.2               |dropout5
# 160               |192               |units6
# 0.1               |0.1               |dropout6
# 512               |224               |units7
# 0.2               |0.2               |dropout7
# 128               |480               |units8
# 0                 |0.3               |dropout8
# 288               |288               |units9
# 0.4               |0.1               |dropout9
# 160               |256               |units10
# 0.2               |0.4               |dropout10
# 192               |64                |units11
# 0.4               |0.1               |dropout11
# 192               |160               |units12
# 0.3               |0                 |dropout12
# 96                |192               |units13
# 0.1               |0.3               |dropout13
# 128               |448               |units14
# 0.1               |0.1               |dropout14
# 416               |128               |units15
# 0.4               |0.3               |dropout15
# 416               |448               |units16
# 0.2               |0.4               |dropout16
# 224               |416               |units17
# 0.2               |0.4               |dropout17
# 96                |320               |units18
# 0.1               |0.5               |dropout18
# 160               |64                |units19
# 0.4               |0.4               |dropout19
# 2                 |2                 |tuner/epochs
# 0                 |0                 |tuner/initial_epoch
# 3                 |3                 |tuner/bracket
# 0                 |0                 |tuner/round
#
# Epoch 1/2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-cbb37be97c4b> in <module>()
# ----> 1 tuner.search(X_train_shuffled, y_train_shuffled, epochs=50, validation_data=(X_val, y_val), callbacks=[stop_early])
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     177
#     178             self.on_trial_begin(trial)
# --> 179             results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     180             # `results` is None indicates user updated oracle in `run_trial()`.
#     181             if results is None:
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/tuners/hyperband.py in run_trial(self, trial, *fit_args, **fit_kwargs)
#     382             fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     383             fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 384         return super(Hyperband, self).run_trial(trial, *fit_args, **fit_kwargs)
#     385
#     386     def _build_model(self, hp):
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/tuner.py in run_trial(self, trial, *args, **kwargs)
#     292             callbacks.append(model_checkpoint)
#     293             copied_kwargs["callbacks"] = callbacks
# --> 294             obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     295
#     296             histories.append(obj_value)
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/tuner.py in _build_and_fit_model(self, trial, *args, **kwargs)
#     220         hp = trial.hyperparameters
#     221         model = self._try_build(hp)
# --> 222         results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     223         return tuner_utils.convert_to_metrics_dict(
#     224             results, self.oracle.objective, "HyperModel.fit()"
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/hypermodel.py in fit(self, hp, model, *args, **kwargs)
#     135             If return a float, it should be the `objective` value.
#     136         """
# --> 137         return model.fit(*args, **kwargs)
#     138
#     139
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     961       # This is the first call of __call__, so we have to initialize.
#     962       initializers = []
# --> 963       self._initialize(args, kwds, add_initializers_to=initializers)
#     964     finally:
#     965       # At this point we know that the initialization is complete (or less
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     784     self._concrete_stateful_fn = (
#     785         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 786             *args, **kwds))
#     787
#     788     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2981       args, kwargs = None, None
#    2982     with self._lock:
# -> 2983       graph_function, _ = self._maybe_define_function(args, kwargs)
#    2984     return graph_function
#    2985
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3290
#    3291           self._function_cache.add_call_context(cache_key.call_context)
# -> 3292           graph_function = self._create_graph_function(args, kwargs)
#    3293           self._function_cache.add(cache_key, cache_key_deletion_observer,
#    3294                                    graph_function)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3138             arg_names=arg_names,
#    3139             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3140             capture_by_value=self._capture_by_value),
#    3141         self._function_attributes,
#    3142         function_spec=self.function_spec,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1159         _, original_func = tf_decorator.unwrap(python_func)
#    1160
# -> 1161       func_outputs = python_func(*func_args, **func_kwargs)
#    1162
#    1163       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     675         # the function a weak reference to itself to avoid a reference cycle.
#     676         with OptionalXlaContext(compile_with_xla):
# --> 677           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     678         return out
#     679
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1141                     recursive=True,
#    1142                     optional_features=autograph_options,
# -> 1143                     user_requested=True,
#    1144                 ))
#    1145           except Exception as e:  # pylint:disable=broad-except
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437     try:
#     438       if kwargs is not None:
# --> 439         result = converted_f(*effective_args, **kwargs)
#     440       else:
#     441         result = converted_f(*effective_args)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     375
#     376   if not options.user_requested and conversion.is_allowlisted(f):
# --> 377     return _call_unconverted(f, args, kwargs, options)
#     378
#     379   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     457   if kwargs is not None:
#     458     return f(*args, **kwargs)
# --> 459   return f(*args)
#     460
#     461
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in step_function(model, iterator)
#    1008             run_step, jit_compile=True, experimental_relax_shapes=True)
#    1009       data = next(iterator)
# -> 1010       outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1011       outputs = reduce_per_replica(
#    1012           outputs, self.distribute_strategy, reduction='first')
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py in run(***failed resolving arguments***)
#    1310       fn = autograph.tf_convert(
#    1311           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1312       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#    1313
#    1314   def reduce(self, reduce_op, value, axis):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    2886       kwargs = {}
#    2887     with self._container_strategy().scope():
# -> 2888       return self._call_for_each_replica(fn, args, kwargs)
#    2889
#    2890   def _call_for_each_replica(self, fn, args, kwargs):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    3687   def _call_for_each_replica(self, fn, args, kwargs):
#    3688     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3689       return fn(*args, **kwargs)
#    3690
#    3691   def _reduce_to(self, reduce_op, value, destinations, options):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     687       try:
#     688         with conversion_ctx:
# --> 689           return converted_call(f, args, kwargs, options=options)
#     690       except Exception as e:  # pylint:disable=broad-except
#     691         if hasattr(e, 'ag_error_metadata'):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     375
#     376   if not options.user_requested and conversion.is_allowlisted(f):
# --> 377     return _call_unconverted(f, args, kwargs, options)
#     378
#     379   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     456
#     457   if kwargs is not None:
# --> 458     return f(*args, **kwargs)
#     459   return f(*args)
#     460
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in run_step(data)
#     998
#     999       def run_step(data):
# -> 1000         outputs = model.train_step(data)
#    1001         # Ensure counter is updated only if `train_step` succeeds.
#    1002         with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in train_step(self, data)
#     857     # Run forward pass.
#     858     with tf.GradientTape() as tape:
# --> 859       y_pred = self(x, training=True)
#     860       loss = self.compute_loss(x, y, y_pred, sample_weight)
#     861     self._validate_target_and_loss(y, loss)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1094         with autocast_variable.enable_auto_cast_variables(
#    1095             self._compute_dtype_object):
# -> 1096           outputs = call_fn(inputs, *args, **kwargs)
#    1097
#    1098         if self._activity_regularizer:
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      90     bound_signature = None
#      91     try:
# ---> 92       return fn(*args, **kwargs)
#      93     except Exception as e:  # pylint: disable=broad-except
#      94       if hasattr(e, '_keras_call_info_injected'):
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py in call(self, inputs, training, mask)
#     372       if not self.built:
#     373         self._init_graph_network(self.inputs, self.outputs)
# --> 374       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     375
#     376     outputs = inputs  # handle the corner case where self.layers is empty
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py in call(self, inputs, training, mask)
#     450     """
#     451     return self._run_internal_graph(
# --> 452         inputs, training=training, mask=mask)
#     453
#     454   def compute_output_shape(self, input_shape):
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     587
#     588         args, kwargs = node.map_arguments(tensor_dict)
# --> 589         outputs = node.layer(*args, **kwargs)
#     590
#     591         # Update tensor_dict.
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     677
#     678     if initial_state is None and constants is None:
# --> 679       return super(RNN, self).__call__(inputs, **kwargs)
#     680
#     681     # If any of `initial_state` or `constants` are specified and are Keras
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1094         with autocast_variable.enable_auto_cast_variables(
#    1095             self._compute_dtype_object):
# -> 1096           outputs = call_fn(inputs, *args, **kwargs)
#    1097
#    1098         if self._activity_regularizer:
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      90     bound_signature = None
#      91     try:
# ---> 92       return fn(*args, **kwargs)
#      93     except Exception as e:  # pylint: disable=broad-except
#      94       if hasattr(e, '_keras_call_info_injected'):
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/recurrent_v2.py in call(self, inputs, mask, training, initial_state)
#    1253         else:
#    1254           (last_output, outputs, new_h, new_c,
# -> 1255            runtime) = lstm_with_backend_selection(**normal_lstm_kwargs)
#    1256
#    1257       states = [new_h, new_c]
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/recurrent_v2.py in lstm_with_backend_selection(inputs, init_h, init_c, kernel, recurrent_kernel, bias, mask, time_major, go_backwards, sequence_lengths, zero_output_for_mask)
#    1649     # grappler will kick in during session execution to optimize the graph.
#    1650     last_output, outputs, new_h, new_c, runtime = defun_standard_lstm(**params)
# -> 1651     _function_register(defun_gpu_lstm, **params)
#    1652
#    1653   return last_output, outputs, new_h, new_c, runtime
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/recurrent_v2.py in _function_register(func, *args, **kwargs)
#    1781     ValueError: When the input function is not a defun wrapped python function.
#    1782   """
# -> 1783   concrete_func = func.get_concrete_function(*args, **kwargs)
#    1784   concrete_func.add_to_graph()
#    1785   concrete_func.add_gradient_functions_to_graph()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in get_concrete_function(self, *args, **kwargs)
#    3069     """
#    3070     graph_function = self._get_concrete_function_garbage_collected(
# -> 3071         *args, **kwargs)
#    3072     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#    3073     return graph_function
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3034       args, kwargs = None, None
#    3035     with self._lock:
# -> 3036       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3037       seen_names = set()
#    3038       captured = object_identity.ObjectIdentitySet(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3290
#    3291           self._function_cache.add_call_context(cache_key.call_context)
# -> 3292           graph_function = self._create_graph_function(args, kwargs)
#    3293           self._function_cache.add(cache_key, cache_key_deletion_observer,
#    3294                                    graph_function)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3138             arg_names=arg_names,
#    3139             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3140             capture_by_value=self._capture_by_value),
#    3141         self._function_attributes,
#    3142         function_spec=self.function_spec,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1159         _, original_func = tf_decorator.unwrap(python_func)
#    1160
# -> 1161       func_outputs = python_func(*func_args, **func_kwargs)
#    1162
#    1163       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/recurrent_v2.py in gpu_lstm_with_fallback(inputs, init_h, init_c, kernel, recurrent_kernel, bias, mask, time_major, go_backwards, sequence_lengths, zero_output_for_mask)
#    1587           time_major=time_major,
#    1588           go_backwards=go_backwards,
# -> 1589           sequence_lengths=sequence_lengths)
#    1590
#    1591     def cudnn_lstm_fn():
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/recurrent_v2.py in gpu_lstm(inputs, init_h, init_c, kernel, recurrent_kernel, bias, mask, time_major, go_backwards, sequence_lengths)
#    1441   # For init_h and init_c, cuDNN expects one more dim of num_layers before or
#    1442   # after batch dim for time major or batch major inputs respectively
# -> 1443   init_h = tf.expand_dims(init_h, axis=seq_axis)
#    1444   init_c = tf.expand_dims(init_c, axis=seq_axis)
#    1445
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1080       # Fallback dispatch system (dispatch v1):
#    1081       try:
# -> 1082         return dispatch_target(*args, **kwargs)
#    1083       except (TypeError, ValueError):
#    1084         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py in expand_dims_v2(input, axis, name)
#     433     InvalidArgumentError: If `axis` is out of range `[-(D+1), D]`.
#     434   """
# --> 435   return gen_array_ops.expand_dims(input, axis, name)
#     436
#     437
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_array_ops.py in expand_dims(input, axis, name)
#    2352   # Add nodes to the TensorFlow graph.
#    2353   _, _, _op, _outputs = _op_def_library._apply_op_helper(
# -> 2354         "ExpandDims", input=input, dim=axis, name=name)
#    2355   _result = _outputs[:]
#    2356   if _execute.must_record_gradient():
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     740       op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     741                                  name=scope, input_types=input_types,
# --> 742                                  attrs=attr_protos, op_def=op_def)
#     743
#     744     # `outputs` is returned as a separate return value so that the output
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     693     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     694         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
# --> 695         compute_device)
#     696
#     697   def capture(self, tensor, name=None, shape=None):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3782           input_types=input_types,
#    3783           original_op=self._default_original_op,
# -> 3784           op_def=op_def)
#    3785       self._create_op_helper(ret, compute_device=compute_device)
#    3786     return ret
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2170         op_def = self._graph._get_op_def(node_def.op)
#    2171       self._c_op = _create_c_op(self._graph, node_def, inputs,
# -> 2172                                 control_input_ops, op_def)
#    2173       name = compat.as_str(node_def.name)
#    2174
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    2008
#    2009   try:
# -> 2010     c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    2011   except errors.InvalidArgumentError as e:
#    2012     # Convert to ValueError for backwards compatibility.
#
# KeyboardInterrupt:

# %%
# Get the top 2 models.
models = tuner.get_best_models(num_models=2)
best_model = models[0]
# Build the model.
# Needed for `Sequential` without specified `input_shape`.
best_model.build(input_shape=(30, 1))
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 256)           264192
#
#  dropout (Dropout)           (None, 30, 256)           0
#
#  lstm_1 (LSTM)               (None, 30, 320)           738560
#
#  dropout_1 (Dropout)         (None, 30, 320)           0
#
#  flatten (Flatten)           (None, 9600)              0
#
#  dense (Dense)               (None, 1)                 9601
#
# =================================================================
# Total params: 1,012,353
# Trainable params: 1,012,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(best_model, show_layer_activations=True, dpi=100)

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=100, verbose=0,
    mode='auto', baseline=None, restore_best_weights=True
)

# %%
hist =  best_model.fit(X_train, y_train, batch_size=120, epochs=2000, verbose=2, validation_data=(X_val, y_val), callbacks=[callback])
score = best_model.evaluate(X_test, y_test, return_dict=True)
y_pred = best_model.predict(X_test)
# Out:
# Epoch 1/2000
# 9/9 - 10s - loss: 31.7890 - mean_absolute_error: 4.4011 - root_mean_squared_error: 5.6382 - mean_absolute_percentage_error: 26.6139 - mean_squared_error: 31.7890 - val_loss: 33.1528 - val_mean_absolute_error: 4.5941 - val_root_mean_squared_error: 5.7578 - val_mean_absolute_percentage_error: 24.1967 - val_mean_squared_error: 33.1528 - 10s/epoch - 1s/step
# Epoch 2/2000
# 9/9 - 5s - loss: 31.3611 - mean_absolute_error: 4.3981 - root_mean_squared_error: 5.6001 - mean_absolute_percentage_error: 28.2480 - mean_squared_error: 31.3611 - val_loss: 34.3717 - val_mean_absolute_error: 4.5998 - val_root_mean_squared_error: 5.8627 - val_mean_absolute_percentage_error: 21.7098 - val_mean_squared_error: 34.3717 - 5s/epoch - 526ms/step
# Epoch 3/2000
# 9/9 - 5s - loss: 28.9415 - mean_absolute_error: 4.2334 - root_mean_squared_error: 5.3797 - mean_absolute_percentage_error: 27.3588 - mean_squared_error: 28.9415 - val_loss: 34.2811 - val_mean_absolute_error: 4.6314 - val_root_mean_squared_error: 5.8550 - val_mean_absolute_percentage_error: 21.5640 - val_mean_squared_error: 34.2811 - 5s/epoch - 530ms/step
# Epoch 4/2000
# 9/9 - 5s - loss: 29.7240 - mean_absolute_error: 4.2614 - root_mean_squared_error: 5.4520 - mean_absolute_percentage_error: 27.0180 - mean_squared_error: 29.7240 - val_loss: 33.1215 - val_mean_absolute_error: 4.5395 - val_root_mean_squared_error: 5.7551 - val_mean_absolute_percentage_error: 21.2970 - val_mean_squared_error: 33.1215 - 5s/epoch - 519ms/step
# Epoch 5/2000
# 9/9 - 5s - loss: 28.6048 - mean_absolute_error: 4.1888 - root_mean_squared_error: 5.3483 - mean_absolute_percentage_error: 26.7705 - mean_squared_error: 28.6048 - val_loss: 31.6516 - val_mean_absolute_error: 4.4481 - val_root_mean_squared_error: 5.6260 - val_mean_absolute_percentage_error: 21.3553 - val_mean_squared_error: 31.6516 - 5s/epoch - 522ms/step
# Epoch 6/2000
# 9/9 - 5s - loss: 28.1716 - mean_absolute_error: 4.1701 - root_mean_squared_error: 5.3077 - mean_absolute_percentage_error: 26.5590 - mean_squared_error: 28.1716 - val_loss: 30.8263 - val_mean_absolute_error: 4.3969 - val_root_mean_squared_error: 5.5521 - val_mean_absolute_percentage_error: 21.3655 - val_mean_squared_error: 30.8263 - 5s/epoch - 521ms/step
# Epoch 7/2000
# 9/9 - 5s - loss: 27.5417 - mean_absolute_error: 4.1153 - root_mean_squared_error: 5.2480 - mean_absolute_percentage_error: 25.9055 - mean_squared_error: 27.5417 - val_loss: 29.8144 - val_mean_absolute_error: 4.3285 - val_root_mean_squared_error: 5.4603 - val_mean_absolute_percentage_error: 21.8457 - val_mean_squared_error: 29.8144 - 5s/epoch - 526ms/step
# Epoch 8/2000
# 9/9 - 5s - loss: 27.5012 - mean_absolute_error: 4.1173 - root_mean_squared_error: 5.2442 - mean_absolute_percentage_error: 26.1909 - mean_squared_error: 27.5012 - val_loss: 29.9050 - val_mean_absolute_error: 4.3377 - val_root_mean_squared_error: 5.4685 - val_mean_absolute_percentage_error: 21.5766 - val_mean_squared_error: 29.9050 - 5s/epoch - 517ms/step
# Epoch 9/2000
# 9/9 - 5s - loss: 27.2954 - mean_absolute_error: 4.0930 - root_mean_squared_error: 5.2245 - mean_absolute_percentage_error: 26.3639 - mean_squared_error: 27.2954 - val_loss: 29.9938 - val_mean_absolute_error: 4.3647 - val_root_mean_squared_error: 5.4767 - val_mean_absolute_percentage_error: 21.2799 - val_mean_squared_error: 29.9938 - 5s/epoch - 524ms/step
# Epoch 10/2000
# 9/9 - 5s - loss: 27.3781 - mean_absolute_error: 4.0957 - root_mean_squared_error: 5.2324 - mean_absolute_percentage_error: 26.1079 - mean_squared_error: 27.3781 - val_loss: 31.4414 - val_mean_absolute_error: 4.4557 - val_root_mean_squared_error: 5.6073 - val_mean_absolute_percentage_error: 21.0728 - val_mean_squared_error: 31.4414 - 5s/epoch - 540ms/step
# Epoch 11/2000
# 9/9 - 5s - loss: 27.0943 - mean_absolute_error: 4.0773 - root_mean_squared_error: 5.2052 - mean_absolute_percentage_error: 25.8368 - mean_squared_error: 27.0943 - val_loss: 30.0078 - val_mean_absolute_error: 4.3696 - val_root_mean_squared_error: 5.4779 - val_mean_absolute_percentage_error: 21.1163 - val_mean_squared_error: 30.0078 - 5s/epoch - 528ms/step
# Epoch 12/2000
# 9/9 - 5s - loss: 26.3567 - mean_absolute_error: 4.0329 - root_mean_squared_error: 5.1339 - mean_absolute_percentage_error: 25.7227 - mean_squared_error: 26.3567 - val_loss: 28.8967 - val_mean_absolute_error: 4.2893 - val_root_mean_squared_error: 5.3756 - val_mean_absolute_percentage_error: 21.4948 - val_mean_squared_error: 28.8967 - 5s/epoch - 534ms/step
# Epoch 13/2000
# 9/9 - 5s - loss: 26.2474 - mean_absolute_error: 4.0311 - root_mean_squared_error: 5.1232 - mean_absolute_percentage_error: 25.6225 - mean_squared_error: 26.2474 - val_loss: 29.3681 - val_mean_absolute_error: 4.3286 - val_root_mean_squared_error: 5.4192 - val_mean_absolute_percentage_error: 20.9825 - val_mean_squared_error: 29.3681 - 5s/epoch - 529ms/step
# Epoch 14/2000
# 9/9 - 5s - loss: 25.9621 - mean_absolute_error: 4.0048 - root_mean_squared_error: 5.0953 - mean_absolute_percentage_error: 25.5372 - mean_squared_error: 25.9621 - val_loss: 29.6903 - val_mean_absolute_error: 4.3403 - val_root_mean_squared_error: 5.4489 - val_mean_absolute_percentage_error: 20.7838 - val_mean_squared_error: 29.6903 - 5s/epoch - 534ms/step
# Epoch 15/2000
# 9/9 - 5s - loss: 25.5007 - mean_absolute_error: 3.9423 - root_mean_squared_error: 5.0498 - mean_absolute_percentage_error: 24.6417 - mean_squared_error: 25.5007 - val_loss: 27.8203 - val_mean_absolute_error: 4.2264 - val_root_mean_squared_error: 5.2745 - val_mean_absolute_percentage_error: 21.3280 - val_mean_squared_error: 27.8203 - 5s/epoch - 527ms/step
# Epoch 16/2000
# 9/9 - 5s - loss: 25.0334 - mean_absolute_error: 3.9268 - root_mean_squared_error: 5.0033 - mean_absolute_percentage_error: 24.9960 - mean_squared_error: 25.0334 - val_loss: 28.2089 - val_mean_absolute_error: 4.2387 - val_root_mean_squared_error: 5.3112 - val_mean_absolute_percentage_error: 20.9034 - val_mean_squared_error: 28.2089 - 5s/epoch - 519ms/step
# Epoch 17/2000
# 9/9 - 5s - loss: 24.6839 - mean_absolute_error: 3.9004 - root_mean_squared_error: 4.9683 - mean_absolute_percentage_error: 24.7516 - mean_squared_error: 24.6839 - val_loss: 27.7520 - val_mean_absolute_error: 4.2363 - val_root_mean_squared_error: 5.2680 - val_mean_absolute_percentage_error: 20.8686 - val_mean_squared_error: 27.7520 - 5s/epoch - 522ms/step
# Epoch 18/2000
# 9/9 - 5s - loss: 24.9130 - mean_absolute_error: 3.9380 - root_mean_squared_error: 4.9913 - mean_absolute_percentage_error: 24.6660 - mean_squared_error: 24.9130 - val_loss: 27.2225 - val_mean_absolute_error: 4.1829 - val_root_mean_squared_error: 5.2175 - val_mean_absolute_percentage_error: 21.6205 - val_mean_squared_error: 27.2225 - 5s/epoch - 516ms/step
# Epoch 19/2000
# 9/9 - 5s - loss: 25.3516 - mean_absolute_error: 3.9563 - root_mean_squared_error: 5.0350 - mean_absolute_percentage_error: 25.2107 - mean_squared_error: 25.3516 - val_loss: 27.7326 - val_mean_absolute_error: 4.2188 - val_root_mean_squared_error: 5.2662 - val_mean_absolute_percentage_error: 22.1115 - val_mean_squared_error: 27.7326 - 5s/epoch - 522ms/step
# Epoch 20/2000
# 9/9 - 5s - loss: 24.6469 - mean_absolute_error: 3.9131 - root_mean_squared_error: 4.9646 - mean_absolute_percentage_error: 24.7593 - mean_squared_error: 24.6469 - val_loss: 27.0208 - val_mean_absolute_error: 4.1752 - val_root_mean_squared_error: 5.1981 - val_mean_absolute_percentage_error: 21.3905 - val_mean_squared_error: 27.0208 - 5s/epoch - 521ms/step
# Epoch 21/2000
# 9/9 - 5s - loss: 24.3651 - mean_absolute_error: 3.8847 - root_mean_squared_error: 4.9361 - mean_absolute_percentage_error: 24.4504 - mean_squared_error: 24.3651 - val_loss: 27.2494 - val_mean_absolute_error: 4.1858 - val_root_mean_squared_error: 5.2201 - val_mean_absolute_percentage_error: 21.1185 - val_mean_squared_error: 27.2494 - 5s/epoch - 519ms/step
# Epoch 22/2000
# 9/9 - 5s - loss: 23.9926 - mean_absolute_error: 3.8338 - root_mean_squared_error: 4.8982 - mean_absolute_percentage_error: 24.3535 - mean_squared_error: 23.9926 - val_loss: 27.3271 - val_mean_absolute_error: 4.1956 - val_root_mean_squared_error: 5.2275 - val_mean_absolute_percentage_error: 20.7013 - val_mean_squared_error: 27.3271 - 5s/epoch - 520ms/step
# Epoch 23/2000
# 9/9 - 5s - loss: 24.2826 - mean_absolute_error: 3.8679 - root_mean_squared_error: 4.9277 - mean_absolute_percentage_error: 24.3033 - mean_squared_error: 24.2826 - val_loss: 27.2783 - val_mean_absolute_error: 4.1985 - val_root_mean_squared_error: 5.2229 - val_mean_absolute_percentage_error: 20.7622 - val_mean_squared_error: 27.2783 - 5s/epoch - 519ms/step
# Epoch 24/2000
# 9/9 - 5s - loss: 23.5580 - mean_absolute_error: 3.8097 - root_mean_squared_error: 4.8537 - mean_absolute_percentage_error: 24.1300 - mean_squared_error: 23.5580 - val_loss: 29.2631 - val_mean_absolute_error: 4.3137 - val_root_mean_squared_error: 5.4095 - val_mean_absolute_percentage_error: 20.4492 - val_mean_squared_error: 29.2631 - 5s/epoch - 519ms/step
# Epoch 25/2000
# 9/9 - 5s - loss: 24.3170 - mean_absolute_error: 3.8462 - root_mean_squared_error: 4.9312 - mean_absolute_percentage_error: 24.0683 - mean_squared_error: 24.3170 - val_loss: 28.4605 - val_mean_absolute_error: 4.2753 - val_root_mean_squared_error: 5.3348 - val_mean_absolute_percentage_error: 20.5345 - val_mean_squared_error: 28.4605 - 5s/epoch - 515ms/step
# Epoch 26/2000
# 9/9 - 5s - loss: 23.3483 - mean_absolute_error: 3.7937 - root_mean_squared_error: 4.8320 - mean_absolute_percentage_error: 23.9649 - mean_squared_error: 23.3483 - val_loss: 26.9181 - val_mean_absolute_error: 4.1681 - val_root_mean_squared_error: 5.1883 - val_mean_absolute_percentage_error: 21.4000 - val_mean_squared_error: 26.9181 - 5s/epoch - 516ms/step
# Epoch 27/2000
# 9/9 - 5s - loss: 23.8275 - mean_absolute_error: 3.8203 - root_mean_squared_error: 4.8813 - mean_absolute_percentage_error: 23.8698 - mean_squared_error: 23.8275 - val_loss: 27.3526 - val_mean_absolute_error: 4.1881 - val_root_mean_squared_error: 5.2300 - val_mean_absolute_percentage_error: 20.6309 - val_mean_squared_error: 27.3526 - 5s/epoch - 520ms/step
# Epoch 28/2000
# 9/9 - 5s - loss: 24.0142 - mean_absolute_error: 3.8646 - root_mean_squared_error: 4.9004 - mean_absolute_percentage_error: 24.3294 - mean_squared_error: 24.0142 - val_loss: 27.0847 - val_mean_absolute_error: 4.1847 - val_root_mean_squared_error: 5.2043 - val_mean_absolute_percentage_error: 21.9186 - val_mean_squared_error: 27.0847 - 5s/epoch - 516ms/step
# Epoch 29/2000
# 9/9 - 5s - loss: 23.7901 - mean_absolute_error: 3.8029 - root_mean_squared_error: 4.8775 - mean_absolute_percentage_error: 24.1227 - mean_squared_error: 23.7901 - val_loss: 27.1500 - val_mean_absolute_error: 4.1779 - val_root_mean_squared_error: 5.2106 - val_mean_absolute_percentage_error: 21.8021 - val_mean_squared_error: 27.1500 - 5s/epoch - 510ms/step
# Epoch 30/2000
# 9/9 - 5s - loss: 24.4127 - mean_absolute_error: 3.8646 - root_mean_squared_error: 4.9409 - mean_absolute_percentage_error: 24.2705 - mean_squared_error: 24.4127 - val_loss: 27.7589 - val_mean_absolute_error: 4.2571 - val_root_mean_squared_error: 5.2687 - val_mean_absolute_percentage_error: 22.7686 - val_mean_squared_error: 27.7589 - 5s/epoch - 523ms/step
# Epoch 31/2000
# 9/9 - 5s - loss: 23.5509 - mean_absolute_error: 3.7985 - root_mean_squared_error: 4.8529 - mean_absolute_percentage_error: 24.0054 - mean_squared_error: 23.5509 - val_loss: 26.5558 - val_mean_absolute_error: 4.1390 - val_root_mean_squared_error: 5.1532 - val_mean_absolute_percentage_error: 20.9793 - val_mean_squared_error: 26.5558 - 5s/epoch - 514ms/step
# Epoch 32/2000
# 9/9 - 5s - loss: 22.9822 - mean_absolute_error: 3.7550 - root_mean_squared_error: 4.7940 - mean_absolute_percentage_error: 23.7367 - mean_squared_error: 22.9822 - val_loss: 26.4620 - val_mean_absolute_error: 4.1281 - val_root_mean_squared_error: 5.1441 - val_mean_absolute_percentage_error: 21.0859 - val_mean_squared_error: 26.4620 - 5s/epoch - 518ms/step
# Epoch 33/2000
# 9/9 - 5s - loss: 23.1063 - mean_absolute_error: 3.7886 - root_mean_squared_error: 4.8069 - mean_absolute_percentage_error: 23.7564 - mean_squared_error: 23.1063 - val_loss: 26.4821 - val_mean_absolute_error: 4.1283 - val_root_mean_squared_error: 5.1461 - val_mean_absolute_percentage_error: 20.9327 - val_mean_squared_error: 26.4821 - 5s/epoch - 529ms/step
# Epoch 34/2000
# 9/9 - 5s - loss: 23.3646 - mean_absolute_error: 3.8171 - root_mean_squared_error: 4.8337 - mean_absolute_percentage_error: 24.0581 - mean_squared_error: 23.3646 - val_loss: 26.6757 - val_mean_absolute_error: 4.1430 - val_root_mean_squared_error: 5.1649 - val_mean_absolute_percentage_error: 20.5613 - val_mean_squared_error: 26.6757 - 5s/epoch - 522ms/step
# Epoch 35/2000
# 9/9 - 5s - loss: 23.2920 - mean_absolute_error: 3.7774 - root_mean_squared_error: 4.8262 - mean_absolute_percentage_error: 23.9038 - mean_squared_error: 23.2920 - val_loss: 26.3346 - val_mean_absolute_error: 4.1253 - val_root_mean_squared_error: 5.1317 - val_mean_absolute_percentage_error: 21.1755 - val_mean_squared_error: 26.3346 - 5s/epoch - 527ms/step
# Epoch 36/2000
# 9/9 - 5s - loss: 22.9337 - mean_absolute_error: 3.7639 - root_mean_squared_error: 4.7889 - mean_absolute_percentage_error: 24.1306 - mean_squared_error: 22.9337 - val_loss: 28.7002 - val_mean_absolute_error: 4.2790 - val_root_mean_squared_error: 5.3573 - val_mean_absolute_percentage_error: 20.3373 - val_mean_squared_error: 28.7002 - 5s/epoch - 519ms/step
# Epoch 37/2000
# 9/9 - 5s - loss: 23.0750 - mean_absolute_error: 3.7660 - root_mean_squared_error: 4.8036 - mean_absolute_percentage_error: 23.3317 - mean_squared_error: 23.0750 - val_loss: 26.4903 - val_mean_absolute_error: 4.1302 - val_root_mean_squared_error: 5.1469 - val_mean_absolute_percentage_error: 20.3583 - val_mean_squared_error: 26.4903 - 5s/epoch - 512ms/step
# Epoch 38/2000
# 9/9 - 5s - loss: 22.3685 - mean_absolute_error: 3.7024 - root_mean_squared_error: 4.7295 - mean_absolute_percentage_error: 23.4544 - mean_squared_error: 22.3685 - val_loss: 28.2162 - val_mean_absolute_error: 4.2593 - val_root_mean_squared_error: 5.3119 - val_mean_absolute_percentage_error: 20.2093 - val_mean_squared_error: 28.2162 - 5s/epoch - 520ms/step
# Epoch 39/2000
# 9/9 - 5s - loss: 22.3518 - mean_absolute_error: 3.7116 - root_mean_squared_error: 4.7278 - mean_absolute_percentage_error: 23.4629 - mean_squared_error: 22.3518 - val_loss: 26.4153 - val_mean_absolute_error: 4.1388 - val_root_mean_squared_error: 5.1396 - val_mean_absolute_percentage_error: 20.4762 - val_mean_squared_error: 26.4153 - 5s/epoch - 525ms/step
# Epoch 40/2000
# 9/9 - 5s - loss: 22.0140 - mean_absolute_error: 3.6636 - root_mean_squared_error: 4.6919 - mean_absolute_percentage_error: 22.9746 - mean_squared_error: 22.0140 - val_loss: 26.3038 - val_mean_absolute_error: 4.1149 - val_root_mean_squared_error: 5.1287 - val_mean_absolute_percentage_error: 20.6869 - val_mean_squared_error: 26.3038 - 5s/epoch - 522ms/step
# Epoch 41/2000
# 9/9 - 5s - loss: 21.6703 - mean_absolute_error: 3.6422 - root_mean_squared_error: 4.6551 - mean_absolute_percentage_error: 22.5719 - mean_squared_error: 21.6703 - val_loss: 27.5059 - val_mean_absolute_error: 4.2300 - val_root_mean_squared_error: 5.2446 - val_mean_absolute_percentage_error: 22.6944 - val_mean_squared_error: 27.5059 - 5s/epoch - 526ms/step
# Epoch 42/2000
# 9/9 - 5s - loss: 23.4737 - mean_absolute_error: 3.8553 - root_mean_squared_error: 4.8450 - mean_absolute_percentage_error: 24.0500 - mean_squared_error: 23.4737 - val_loss: 26.8488 - val_mean_absolute_error: 4.1577 - val_root_mean_squared_error: 5.1816 - val_mean_absolute_percentage_error: 22.0553 - val_mean_squared_error: 26.8488 - 5s/epoch - 527ms/step
# Epoch 43/2000
# 9/9 - 5s - loss: 22.8540 - mean_absolute_error: 3.7526 - root_mean_squared_error: 4.7806 - mean_absolute_percentage_error: 23.8168 - mean_squared_error: 22.8540 - val_loss: 26.2038 - val_mean_absolute_error: 4.0834 - val_root_mean_squared_error: 5.1190 - val_mean_absolute_percentage_error: 20.1775 - val_mean_squared_error: 26.2038 - 5s/epoch - 524ms/step
# Epoch 44/2000
# 9/9 - 5s - loss: 21.8643 - mean_absolute_error: 3.6542 - root_mean_squared_error: 4.6759 - mean_absolute_percentage_error: 23.2246 - mean_squared_error: 21.8643 - val_loss: 27.2565 - val_mean_absolute_error: 4.1809 - val_root_mean_squared_error: 5.2208 - val_mean_absolute_percentage_error: 20.0048 - val_mean_squared_error: 27.2565 - 5s/epoch - 517ms/step
# Epoch 45/2000
# 9/9 - 5s - loss: 22.4970 - mean_absolute_error: 3.7136 - root_mean_squared_error: 4.7431 - mean_absolute_percentage_error: 23.4098 - mean_squared_error: 22.4970 - val_loss: 27.3869 - val_mean_absolute_error: 4.1931 - val_root_mean_squared_error: 5.2333 - val_mean_absolute_percentage_error: 20.0154 - val_mean_squared_error: 27.3869 - 5s/epoch - 518ms/step
# Epoch 46/2000
# 9/9 - 5s - loss: 21.8575 - mean_absolute_error: 3.6528 - root_mean_squared_error: 4.6752 - mean_absolute_percentage_error: 23.0774 - mean_squared_error: 21.8575 - val_loss: 27.4182 - val_mean_absolute_error: 4.2040 - val_root_mean_squared_error: 5.2362 - val_mean_absolute_percentage_error: 20.1044 - val_mean_squared_error: 27.4182 - 5s/epoch - 527ms/step
# Epoch 47/2000
# 9/9 - 5s - loss: 22.1003 - mean_absolute_error: 3.6893 - root_mean_squared_error: 4.7011 - mean_absolute_percentage_error: 22.9761 - mean_squared_error: 22.1003 - val_loss: 26.4955 - val_mean_absolute_error: 4.1264 - val_root_mean_squared_error: 5.1474 - val_mean_absolute_percentage_error: 20.3116 - val_mean_squared_error: 26.4955 - 5s/epoch - 518ms/step
# Epoch 48/2000
# 9/9 - 5s - loss: 21.1433 - mean_absolute_error: 3.5853 - root_mean_squared_error: 4.5982 - mean_absolute_percentage_error: 22.5112 - mean_squared_error: 21.1433 - val_loss: 26.2799 - val_mean_absolute_error: 4.1061 - val_root_mean_squared_error: 5.1264 - val_mean_absolute_percentage_error: 20.1389 - val_mean_squared_error: 26.2799 - 5s/epoch - 520ms/step
# Epoch 49/2000
# 9/9 - 5s - loss: 21.0470 - mean_absolute_error: 3.5994 - root_mean_squared_error: 4.5877 - mean_absolute_percentage_error: 22.5753 - mean_squared_error: 21.0470 - val_loss: 25.9396 - val_mean_absolute_error: 4.0876 - val_root_mean_squared_error: 5.0931 - val_mean_absolute_percentage_error: 20.5084 - val_mean_squared_error: 25.9396 - 5s/epoch - 522ms/step
# Epoch 50/2000
# 9/9 - 5s - loss: 20.9286 - mean_absolute_error: 3.5932 - root_mean_squared_error: 4.5748 - mean_absolute_percentage_error: 22.7071 - mean_squared_error: 20.9286 - val_loss: 26.4754 - val_mean_absolute_error: 4.1237 - val_root_mean_squared_error: 5.1454 - val_mean_absolute_percentage_error: 20.3817 - val_mean_squared_error: 26.4754 - 5s/epoch - 525ms/step
# Epoch 51/2000
# 9/9 - 5s - loss: 20.8898 - mean_absolute_error: 3.5877 - root_mean_squared_error: 4.5705 - mean_absolute_percentage_error: 22.5132 - mean_squared_error: 20.8898 - val_loss: 27.6070 - val_mean_absolute_error: 4.1941 - val_root_mean_squared_error: 5.2542 - val_mean_absolute_percentage_error: 20.0386 - val_mean_squared_error: 27.6070 - 5s/epoch - 527ms/step
# Epoch 52/2000
# 9/9 - 5s - loss: 20.8829 - mean_absolute_error: 3.5906 - root_mean_squared_error: 4.5698 - mean_absolute_percentage_error: 22.4428 - mean_squared_error: 20.8829 - val_loss: 26.9576 - val_mean_absolute_error: 4.1486 - val_root_mean_squared_error: 5.1921 - val_mean_absolute_percentage_error: 19.8705 - val_mean_squared_error: 26.9576 - 5s/epoch - 527ms/step
# Epoch 53/2000
# 9/9 - 5s - loss: 21.2540 - mean_absolute_error: 3.6082 - root_mean_squared_error: 4.6102 - mean_absolute_percentage_error: 22.3552 - mean_squared_error: 21.2540 - val_loss: 27.2091 - val_mean_absolute_error: 4.1305 - val_root_mean_squared_error: 5.2162 - val_mean_absolute_percentage_error: 20.1362 - val_mean_squared_error: 27.2091 - 5s/epoch - 527ms/step
# Epoch 54/2000
# 9/9 - 5s - loss: 20.8331 - mean_absolute_error: 3.5921 - root_mean_squared_error: 4.5643 - mean_absolute_percentage_error: 22.3931 - mean_squared_error: 20.8331 - val_loss: 26.8648 - val_mean_absolute_error: 4.1347 - val_root_mean_squared_error: 5.1831 - val_mean_absolute_percentage_error: 20.0773 - val_mean_squared_error: 26.8648 - 5s/epoch - 528ms/step
# Epoch 55/2000
# 9/9 - 5s - loss: 20.2597 - mean_absolute_error: 3.5457 - root_mean_squared_error: 4.5011 - mean_absolute_percentage_error: 22.2604 - mean_squared_error: 20.2597 - val_loss: 26.2363 - val_mean_absolute_error: 4.0968 - val_root_mean_squared_error: 5.1221 - val_mean_absolute_percentage_error: 20.5438 - val_mean_squared_error: 26.2363 - 5s/epoch - 529ms/step
# Epoch 56/2000
# 9/9 - 5s - loss: 20.1935 - mean_absolute_error: 3.5380 - root_mean_squared_error: 4.4937 - mean_absolute_percentage_error: 22.1955 - mean_squared_error: 20.1935 - val_loss: 26.1408 - val_mean_absolute_error: 4.0741 - val_root_mean_squared_error: 5.1128 - val_mean_absolute_percentage_error: 20.1604 - val_mean_squared_error: 26.1408 - 5s/epoch - 514ms/step
# Epoch 57/2000
# 9/9 - 5s - loss: 19.8602 - mean_absolute_error: 3.5021 - root_mean_squared_error: 4.4565 - mean_absolute_percentage_error: 21.9642 - mean_squared_error: 19.8602 - val_loss: 27.4708 - val_mean_absolute_error: 4.1672 - val_root_mean_squared_error: 5.2413 - val_mean_absolute_percentage_error: 20.1359 - val_mean_squared_error: 27.4708 - 5s/epoch - 517ms/step
# Epoch 58/2000
# 9/9 - 5s - loss: 19.9004 - mean_absolute_error: 3.5191 - root_mean_squared_error: 4.4610 - mean_absolute_percentage_error: 21.8904 - mean_squared_error: 19.9004 - val_loss: 26.6761 - val_mean_absolute_error: 4.1475 - val_root_mean_squared_error: 5.1649 - val_mean_absolute_percentage_error: 21.7411 - val_mean_squared_error: 26.6761 - 5s/epoch - 527ms/step
# Epoch 59/2000
# 9/9 - 5s - loss: 20.1475 - mean_absolute_error: 3.5347 - root_mean_squared_error: 4.4886 - mean_absolute_percentage_error: 21.9585 - mean_squared_error: 20.1475 - val_loss: 26.0000 - val_mean_absolute_error: 4.0575 - val_root_mean_squared_error: 5.0990 - val_mean_absolute_percentage_error: 20.6276 - val_mean_squared_error: 26.0000 - 5s/epoch - 517ms/step
# Epoch 60/2000
# 9/9 - 5s - loss: 19.6375 - mean_absolute_error: 3.4924 - root_mean_squared_error: 4.4314 - mean_absolute_percentage_error: 21.7840 - mean_squared_error: 19.6375 - val_loss: 26.4975 - val_mean_absolute_error: 4.1266 - val_root_mean_squared_error: 5.1476 - val_mean_absolute_percentage_error: 21.5939 - val_mean_squared_error: 26.4975 - 5s/epoch - 522ms/step
# Epoch 61/2000
# 9/9 - 5s - loss: 19.4439 - mean_absolute_error: 3.4752 - root_mean_squared_error: 4.4095 - mean_absolute_percentage_error: 21.7248 - mean_squared_error: 19.4439 - val_loss: 26.6220 - val_mean_absolute_error: 4.1393 - val_root_mean_squared_error: 5.1597 - val_mean_absolute_percentage_error: 21.1369 - val_mean_squared_error: 26.6220 - 5s/epoch - 542ms/step
# Epoch 62/2000
# 9/9 - 5s - loss: 19.6878 - mean_absolute_error: 3.4949 - root_mean_squared_error: 4.4371 - mean_absolute_percentage_error: 21.8502 - mean_squared_error: 19.6878 - val_loss: 27.1535 - val_mean_absolute_error: 4.1596 - val_root_mean_squared_error: 5.2109 - val_mean_absolute_percentage_error: 20.5975 - val_mean_squared_error: 27.1535 - 5s/epoch - 523ms/step
# Epoch 63/2000
# 9/9 - 5s - loss: 19.3077 - mean_absolute_error: 3.4752 - root_mean_squared_error: 4.3941 - mean_absolute_percentage_error: 21.5755 - mean_squared_error: 19.3077 - val_loss: 27.7058 - val_mean_absolute_error: 4.1775 - val_root_mean_squared_error: 5.2636 - val_mean_absolute_percentage_error: 20.7681 - val_mean_squared_error: 27.7058 - 5s/epoch - 561ms/step
# Epoch 64/2000
# 9/9 - 6s - loss: 19.0584 - mean_absolute_error: 3.4496 - root_mean_squared_error: 4.3656 - mean_absolute_percentage_error: 21.4705 - mean_squared_error: 19.0584 - val_loss: 26.4314 - val_mean_absolute_error: 4.1075 - val_root_mean_squared_error: 5.1411 - val_mean_absolute_percentage_error: 20.6911 - val_mean_squared_error: 26.4314 - 6s/epoch - 692ms/step
# Epoch 65/2000
# 9/9 - 5s - loss: 19.2641 - mean_absolute_error: 3.4528 - root_mean_squared_error: 4.3891 - mean_absolute_percentage_error: 21.4503 - mean_squared_error: 19.2641 - val_loss: 27.1582 - val_mean_absolute_error: 4.1573 - val_root_mean_squared_error: 5.2113 - val_mean_absolute_percentage_error: 21.0536 - val_mean_squared_error: 27.1582 - 5s/epoch - 525ms/step
# Epoch 66/2000
# 9/9 - 5s - loss: 18.4962 - mean_absolute_error: 3.3914 - root_mean_squared_error: 4.3007 - mean_absolute_percentage_error: 21.0031 - mean_squared_error: 18.4962 - val_loss: 26.6924 - val_mean_absolute_error: 4.1438 - val_root_mean_squared_error: 5.1665 - val_mean_absolute_percentage_error: 21.1053 - val_mean_squared_error: 26.6924 - 5s/epoch - 529ms/step
# Epoch 67/2000
# 9/9 - 5s - loss: 18.6167 - mean_absolute_error: 3.4033 - root_mean_squared_error: 4.3147 - mean_absolute_percentage_error: 21.3344 - mean_squared_error: 18.6167 - val_loss: 27.2134 - val_mean_absolute_error: 4.1505 - val_root_mean_squared_error: 5.2166 - val_mean_absolute_percentage_error: 20.7816 - val_mean_squared_error: 27.2134 - 5s/epoch - 522ms/step
# Epoch 68/2000
# 9/9 - 5s - loss: 18.6726 - mean_absolute_error: 3.3918 - root_mean_squared_error: 4.3212 - mean_absolute_percentage_error: 21.1787 - mean_squared_error: 18.6726 - val_loss: 26.4479 - val_mean_absolute_error: 4.1290 - val_root_mean_squared_error: 5.1428 - val_mean_absolute_percentage_error: 21.0548 - val_mean_squared_error: 26.4479 - 5s/epoch - 534ms/step
# Epoch 69/2000
# 9/9 - 5s - loss: 18.6734 - mean_absolute_error: 3.4422 - root_mean_squared_error: 4.3213 - mean_absolute_percentage_error: 21.1610 - mean_squared_error: 18.6734 - val_loss: 27.1296 - val_mean_absolute_error: 4.1607 - val_root_mean_squared_error: 5.2086 - val_mean_absolute_percentage_error: 21.3365 - val_mean_squared_error: 27.1296 - 5s/epoch - 524ms/step
# Epoch 70/2000
# 9/9 - 5s - loss: 19.1183 - mean_absolute_error: 3.4525 - root_mean_squared_error: 4.3724 - mean_absolute_percentage_error: 21.6686 - mean_squared_error: 19.1183 - val_loss: 27.4962 - val_mean_absolute_error: 4.1950 - val_root_mean_squared_error: 5.2437 - val_mean_absolute_percentage_error: 21.9667 - val_mean_squared_error: 27.4962 - 5s/epoch - 529ms/step
# Epoch 71/2000
# 9/9 - 5s - loss: 18.5855 - mean_absolute_error: 3.3756 - root_mean_squared_error: 4.3111 - mean_absolute_percentage_error: 21.2620 - mean_squared_error: 18.5855 - val_loss: 27.1352 - val_mean_absolute_error: 4.1454 - val_root_mean_squared_error: 5.2091 - val_mean_absolute_percentage_error: 20.8001 - val_mean_squared_error: 27.1352 - 5s/epoch - 524ms/step
# Epoch 72/2000
# 9/9 - 5s - loss: 18.7160 - mean_absolute_error: 3.4011 - root_mean_squared_error: 4.3262 - mean_absolute_percentage_error: 20.9137 - mean_squared_error: 18.7160 - val_loss: 27.2007 - val_mean_absolute_error: 4.1512 - val_root_mean_squared_error: 5.2154 - val_mean_absolute_percentage_error: 21.3602 - val_mean_squared_error: 27.2007 - 5s/epoch - 533ms/step
# Epoch 73/2000
# 9/9 - 5s - loss: 18.9423 - mean_absolute_error: 3.4077 - root_mean_squared_error: 4.3523 - mean_absolute_percentage_error: 21.4002 - mean_squared_error: 18.9423 - val_loss: 27.3277 - val_mean_absolute_error: 4.1891 - val_root_mean_squared_error: 5.2276 - val_mean_absolute_percentage_error: 21.8091 - val_mean_squared_error: 27.3277 - 5s/epoch - 530ms/step
# Epoch 74/2000
# 9/9 - 5s - loss: 18.1422 - mean_absolute_error: 3.3343 - root_mean_squared_error: 4.2594 - mean_absolute_percentage_error: 20.8517 - mean_squared_error: 18.1422 - val_loss: 27.8662 - val_mean_absolute_error: 4.1921 - val_root_mean_squared_error: 5.2788 - val_mean_absolute_percentage_error: 21.2047 - val_mean_squared_error: 27.8662 - 5s/epoch - 535ms/step
# Epoch 75/2000
# 9/9 - 5s - loss: 17.8420 - mean_absolute_error: 3.3710 - root_mean_squared_error: 4.2240 - mean_absolute_percentage_error: 20.9341 - mean_squared_error: 17.8420 - val_loss: 26.8451 - val_mean_absolute_error: 4.1342 - val_root_mean_squared_error: 5.1812 - val_mean_absolute_percentage_error: 21.0949 - val_mean_squared_error: 26.8451 - 5s/epoch - 529ms/step
# Epoch 76/2000
# 9/9 - 5s - loss: 17.9843 - mean_absolute_error: 3.3367 - root_mean_squared_error: 4.2408 - mean_absolute_percentage_error: 21.1096 - mean_squared_error: 17.9843 - val_loss: 27.5726 - val_mean_absolute_error: 4.1607 - val_root_mean_squared_error: 5.2510 - val_mean_absolute_percentage_error: 21.0020 - val_mean_squared_error: 27.5726 - 5s/epoch - 528ms/step
# Epoch 77/2000
# 9/9 - 5s - loss: 17.4949 - mean_absolute_error: 3.2934 - root_mean_squared_error: 4.1827 - mean_absolute_percentage_error: 20.3187 - mean_squared_error: 17.4949 - val_loss: 28.0023 - val_mean_absolute_error: 4.2278 - val_root_mean_squared_error: 5.2917 - val_mean_absolute_percentage_error: 21.4509 - val_mean_squared_error: 28.0023 - 5s/epoch - 538ms/step
# Epoch 78/2000
# 9/9 - 5s - loss: 16.8699 - mean_absolute_error: 3.2297 - root_mean_squared_error: 4.1073 - mean_absolute_percentage_error: 20.3106 - mean_squared_error: 16.8699 - val_loss: 27.9503 - val_mean_absolute_error: 4.1826 - val_root_mean_squared_error: 5.2868 - val_mean_absolute_percentage_error: 20.3516 - val_mean_squared_error: 27.9503 - 5s/epoch - 551ms/step
# Epoch 79/2000
# 9/9 - 5s - loss: 17.0469 - mean_absolute_error: 3.2622 - root_mean_squared_error: 4.1288 - mean_absolute_percentage_error: 20.2667 - mean_squared_error: 17.0469 - val_loss: 30.9991 - val_mean_absolute_error: 4.3794 - val_root_mean_squared_error: 5.5677 - val_mean_absolute_percentage_error: 21.1859 - val_mean_squared_error: 30.9991 - 5s/epoch - 540ms/step
# Epoch 80/2000
# 9/9 - 5s - loss: 16.9582 - mean_absolute_error: 3.2679 - root_mean_squared_error: 4.1180 - mean_absolute_percentage_error: 20.2257 - mean_squared_error: 16.9582 - val_loss: 29.0969 - val_mean_absolute_error: 4.2760 - val_root_mean_squared_error: 5.3942 - val_mean_absolute_percentage_error: 21.3869 - val_mean_squared_error: 29.0969 - 5s/epoch - 530ms/step
# Epoch 81/2000
# 9/9 - 5s - loss: 16.5862 - mean_absolute_error: 3.2129 - root_mean_squared_error: 4.0726 - mean_absolute_percentage_error: 19.7827 - mean_squared_error: 16.5862 - val_loss: 30.5996 - val_mean_absolute_error: 4.4869 - val_root_mean_squared_error: 5.5317 - val_mean_absolute_percentage_error: 23.8844 - val_mean_squared_error: 30.5996 - 5s/epoch - 518ms/step
# Epoch 82/2000
# 9/9 - 5s - loss: 16.9514 - mean_absolute_error: 3.2538 - root_mean_squared_error: 4.1172 - mean_absolute_percentage_error: 20.1271 - mean_squared_error: 16.9514 - val_loss: 28.7398 - val_mean_absolute_error: 4.3158 - val_root_mean_squared_error: 5.3609 - val_mean_absolute_percentage_error: 22.6532 - val_mean_squared_error: 28.7398 - 5s/epoch - 513ms/step
# Epoch 83/2000
# 9/9 - 5s - loss: 16.3028 - mean_absolute_error: 3.1763 - root_mean_squared_error: 4.0377 - mean_absolute_percentage_error: 19.8037 - mean_squared_error: 16.3028 - val_loss: 29.2562 - val_mean_absolute_error: 4.2924 - val_root_mean_squared_error: 5.4089 - val_mean_absolute_percentage_error: 21.6594 - val_mean_squared_error: 29.2562 - 5s/epoch - 524ms/step
# Epoch 84/2000
# 9/9 - 5s - loss: 15.9507 - mean_absolute_error: 3.1381 - root_mean_squared_error: 3.9938 - mean_absolute_percentage_error: 19.3958 - mean_squared_error: 15.9507 - val_loss: 29.2809 - val_mean_absolute_error: 4.3107 - val_root_mean_squared_error: 5.4112 - val_mean_absolute_percentage_error: 21.3005 - val_mean_squared_error: 29.2809 - 5s/epoch - 514ms/step
# Epoch 85/2000
# 9/9 - 5s - loss: 15.7530 - mean_absolute_error: 3.1132 - root_mean_squared_error: 3.9690 - mean_absolute_percentage_error: 19.4402 - mean_squared_error: 15.7530 - val_loss: 27.8846 - val_mean_absolute_error: 4.1714 - val_root_mean_squared_error: 5.2806 - val_mean_absolute_percentage_error: 20.9669 - val_mean_squared_error: 27.8846 - 5s/epoch - 529ms/step
# Epoch 86/2000
# 9/9 - 5s - loss: 15.8017 - mean_absolute_error: 3.1324 - root_mean_squared_error: 3.9751 - mean_absolute_percentage_error: 19.2225 - mean_squared_error: 15.8017 - val_loss: 30.5686 - val_mean_absolute_error: 4.3820 - val_root_mean_squared_error: 5.5289 - val_mean_absolute_percentage_error: 22.1239 - val_mean_squared_error: 30.5686 - 5s/epoch - 521ms/step
# Epoch 87/2000
# 9/9 - 5s - loss: 15.1489 - mean_absolute_error: 3.0783 - root_mean_squared_error: 3.8922 - mean_absolute_percentage_error: 18.9809 - mean_squared_error: 15.1489 - val_loss: 28.7119 - val_mean_absolute_error: 4.2795 - val_root_mean_squared_error: 5.3583 - val_mean_absolute_percentage_error: 21.9095 - val_mean_squared_error: 28.7119 - 5s/epoch - 524ms/step
# Epoch 88/2000
# 9/9 - 5s - loss: 15.1915 - mean_absolute_error: 3.0728 - root_mean_squared_error: 3.8976 - mean_absolute_percentage_error: 19.2142 - mean_squared_error: 15.1915 - val_loss: 30.5936 - val_mean_absolute_error: 4.3677 - val_root_mean_squared_error: 5.5311 - val_mean_absolute_percentage_error: 21.3610 - val_mean_squared_error: 30.5936 - 5s/epoch - 516ms/step
# Epoch 89/2000
# 9/9 - 5s - loss: 15.0114 - mean_absolute_error: 2.9977 - root_mean_squared_error: 3.8745 - mean_absolute_percentage_error: 18.2983 - mean_squared_error: 15.0114 - val_loss: 30.1004 - val_mean_absolute_error: 4.3447 - val_root_mean_squared_error: 5.4864 - val_mean_absolute_percentage_error: 21.6185 - val_mean_squared_error: 30.1004 - 5s/epoch - 520ms/step
# Epoch 90/2000
# 9/9 - 5s - loss: 15.3288 - mean_absolute_error: 3.0870 - root_mean_squared_error: 3.9152 - mean_absolute_percentage_error: 18.7771 - mean_squared_error: 15.3288 - val_loss: 30.7409 - val_mean_absolute_error: 4.4191 - val_root_mean_squared_error: 5.5445 - val_mean_absolute_percentage_error: 21.8996 - val_mean_squared_error: 30.7409 - 5s/epoch - 517ms/step
# Epoch 91/2000
# 9/9 - 5s - loss: 15.6497 - mean_absolute_error: 3.1283 - root_mean_squared_error: 3.9560 - mean_absolute_percentage_error: 19.3849 - mean_squared_error: 15.6497 - val_loss: 28.8638 - val_mean_absolute_error: 4.3079 - val_root_mean_squared_error: 5.3725 - val_mean_absolute_percentage_error: 22.2018 - val_mean_squared_error: 28.8638 - 5s/epoch - 517ms/step
# Epoch 92/2000
# 9/9 - 5s - loss: 14.2068 - mean_absolute_error: 2.9786 - root_mean_squared_error: 3.7692 - mean_absolute_percentage_error: 18.2178 - mean_squared_error: 14.2068 - val_loss: 29.2349 - val_mean_absolute_error: 4.2827 - val_root_mean_squared_error: 5.4069 - val_mean_absolute_percentage_error: 22.0434 - val_mean_squared_error: 29.2349 - 5s/epoch - 523ms/step
# Epoch 93/2000
# 9/9 - 5s - loss: 13.3688 - mean_absolute_error: 2.8774 - root_mean_squared_error: 3.6563 - mean_absolute_percentage_error: 17.8510 - mean_squared_error: 13.3688 - val_loss: 33.3187 - val_mean_absolute_error: 4.5710 - val_root_mean_squared_error: 5.7722 - val_mean_absolute_percentage_error: 22.3209 - val_mean_squared_error: 33.3187 - 5s/epoch - 519ms/step
# Epoch 94/2000
# 9/9 - 5s - loss: 14.3031 - mean_absolute_error: 2.9692 - root_mean_squared_error: 3.7819 - mean_absolute_percentage_error: 17.9174 - mean_squared_error: 14.3031 - val_loss: 31.0305 - val_mean_absolute_error: 4.4272 - val_root_mean_squared_error: 5.5705 - val_mean_absolute_percentage_error: 21.8221 - val_mean_squared_error: 31.0305 - 5s/epoch - 523ms/step
# Epoch 95/2000
# 9/9 - 5s - loss: 14.5128 - mean_absolute_error: 3.0059 - root_mean_squared_error: 3.8096 - mean_absolute_percentage_error: 18.2441 - mean_squared_error: 14.5128 - val_loss: 30.7453 - val_mean_absolute_error: 4.4275 - val_root_mean_squared_error: 5.5448 - val_mean_absolute_percentage_error: 21.8835 - val_mean_squared_error: 30.7453 - 5s/epoch - 526ms/step
# Epoch 96/2000
# 9/9 - 5s - loss: 13.4656 - mean_absolute_error: 2.8830 - root_mean_squared_error: 3.6695 - mean_absolute_percentage_error: 17.8479 - mean_squared_error: 13.4656 - val_loss: 29.9385 - val_mean_absolute_error: 4.3460 - val_root_mean_squared_error: 5.4716 - val_mean_absolute_percentage_error: 21.9028 - val_mean_squared_error: 29.9385 - 5s/epoch - 522ms/step
# Epoch 97/2000
# 9/9 - 5s - loss: 12.9572 - mean_absolute_error: 2.8270 - root_mean_squared_error: 3.5996 - mean_absolute_percentage_error: 17.0125 - mean_squared_error: 12.9572 - val_loss: 30.5141 - val_mean_absolute_error: 4.3854 - val_root_mean_squared_error: 5.5240 - val_mean_absolute_percentage_error: 22.8758 - val_mean_squared_error: 30.5141 - 5s/epoch - 528ms/step
# Epoch 98/2000
# 9/9 - 5s - loss: 12.5643 - mean_absolute_error: 2.7858 - root_mean_squared_error: 3.5446 - mean_absolute_percentage_error: 17.0410 - mean_squared_error: 12.5643 - val_loss: 30.2987 - val_mean_absolute_error: 4.3703 - val_root_mean_squared_error: 5.5044 - val_mean_absolute_percentage_error: 22.5095 - val_mean_squared_error: 30.2987 - 5s/epoch - 521ms/step
# Epoch 99/2000
# 9/9 - 5s - loss: 12.4840 - mean_absolute_error: 2.7768 - root_mean_squared_error: 3.5333 - mean_absolute_percentage_error: 17.1229 - mean_squared_error: 12.4840 - val_loss: 30.7607 - val_mean_absolute_error: 4.3660 - val_root_mean_squared_error: 5.5462 - val_mean_absolute_percentage_error: 21.6382 - val_mean_squared_error: 30.7607 - 5s/epoch - 537ms/step
# Epoch 100/2000
# 9/9 - 5s - loss: 12.4153 - mean_absolute_error: 2.7911 - root_mean_squared_error: 3.5235 - mean_absolute_percentage_error: 17.0510 - mean_squared_error: 12.4153 - val_loss: 30.7470 - val_mean_absolute_error: 4.3877 - val_root_mean_squared_error: 5.5450 - val_mean_absolute_percentage_error: 22.0626 - val_mean_squared_error: 30.7470 - 5s/epoch - 523ms/step
# Epoch 101/2000
# 9/9 - 5s - loss: 11.5412 - mean_absolute_error: 2.6810 - root_mean_squared_error: 3.3972 - mean_absolute_percentage_error: 16.3493 - mean_squared_error: 11.5412 - val_loss: 30.0162 - val_mean_absolute_error: 4.3706 - val_root_mean_squared_error: 5.4787 - val_mean_absolute_percentage_error: 22.3312 - val_mean_squared_error: 30.0162 - 5s/epoch - 521ms/step
# Epoch 102/2000
# 9/9 - 5s - loss: 12.8310 - mean_absolute_error: 2.7962 - root_mean_squared_error: 3.5820 - mean_absolute_percentage_error: 17.0755 - mean_squared_error: 12.8310 - val_loss: 30.4031 - val_mean_absolute_error: 4.4294 - val_root_mean_squared_error: 5.5139 - val_mean_absolute_percentage_error: 22.3386 - val_mean_squared_error: 30.4031 - 5s/epoch - 519ms/step
# Epoch 103/2000
# 9/9 - 5s - loss: 11.8033 - mean_absolute_error: 2.7163 - root_mean_squared_error: 3.4356 - mean_absolute_percentage_error: 16.5540 - mean_squared_error: 11.8033 - val_loss: 30.4764 - val_mean_absolute_error: 4.4111 - val_root_mean_squared_error: 5.5205 - val_mean_absolute_percentage_error: 22.2119 - val_mean_squared_error: 30.4764 - 5s/epoch - 527ms/step
# Epoch 104/2000
# 9/9 - 5s - loss: 11.6297 - mean_absolute_error: 2.6605 - root_mean_squared_error: 3.4102 - mean_absolute_percentage_error: 16.2691 - mean_squared_error: 11.6297 - val_loss: 32.3454 - val_mean_absolute_error: 4.5246 - val_root_mean_squared_error: 5.6873 - val_mean_absolute_percentage_error: 22.0542 - val_mean_squared_error: 32.3454 - 5s/epoch - 519ms/step
# Epoch 105/2000
# 9/9 - 5s - loss: 11.5607 - mean_absolute_error: 2.6737 - root_mean_squared_error: 3.4001 - mean_absolute_percentage_error: 16.2774 - mean_squared_error: 11.5607 - val_loss: 31.6328 - val_mean_absolute_error: 4.4567 - val_root_mean_squared_error: 5.6243 - val_mean_absolute_percentage_error: 22.4746 - val_mean_squared_error: 31.6328 - 5s/epoch - 522ms/step
# Epoch 106/2000
# 9/9 - 5s - loss: 11.5778 - mean_absolute_error: 2.6788 - root_mean_squared_error: 3.4026 - mean_absolute_percentage_error: 16.3575 - mean_squared_error: 11.5778 - val_loss: 31.0413 - val_mean_absolute_error: 4.4437 - val_root_mean_squared_error: 5.5715 - val_mean_absolute_percentage_error: 23.4571 - val_mean_squared_error: 31.0413 - 5s/epoch - 524ms/step
# Epoch 107/2000
# 9/9 - 5s - loss: 11.7657 - mean_absolute_error: 2.6517 - root_mean_squared_error: 3.4301 - mean_absolute_percentage_error: 16.3434 - mean_squared_error: 11.7657 - val_loss: 33.0172 - val_mean_absolute_error: 4.5928 - val_root_mean_squared_error: 5.7461 - val_mean_absolute_percentage_error: 22.6675 - val_mean_squared_error: 33.0172 - 5s/epoch - 516ms/step
# Epoch 108/2000
# 9/9 - 5s - loss: 11.0452 - mean_absolute_error: 2.5675 - root_mean_squared_error: 3.3234 - mean_absolute_percentage_error: 15.4343 - mean_squared_error: 11.0452 - val_loss: 32.1826 - val_mean_absolute_error: 4.4889 - val_root_mean_squared_error: 5.6730 - val_mean_absolute_percentage_error: 22.1768 - val_mean_squared_error: 32.1826 - 5s/epoch - 521ms/step
# Epoch 109/2000
# 9/9 - 5s - loss: 10.3744 - mean_absolute_error: 2.5267 - root_mean_squared_error: 3.2209 - mean_absolute_percentage_error: 15.2016 - mean_squared_error: 10.3744 - val_loss: 31.0371 - val_mean_absolute_error: 4.4531 - val_root_mean_squared_error: 5.5711 - val_mean_absolute_percentage_error: 21.9998 - val_mean_squared_error: 31.0371 - 5s/epoch - 528ms/step
# Epoch 110/2000
# 9/9 - 5s - loss: 9.4015 - mean_absolute_error: 2.3611 - root_mean_squared_error: 3.0662 - mean_absolute_percentage_error: 14.2308 - mean_squared_error: 9.4015 - val_loss: 31.8851 - val_mean_absolute_error: 4.4571 - val_root_mean_squared_error: 5.6467 - val_mean_absolute_percentage_error: 22.2586 - val_mean_squared_error: 31.8851 - 5s/epoch - 521ms/step
# Epoch 111/2000
# 9/9 - 5s - loss: 9.0966 - mean_absolute_error: 2.3506 - root_mean_squared_error: 3.0161 - mean_absolute_percentage_error: 14.0592 - mean_squared_error: 9.0966 - val_loss: 32.0006 - val_mean_absolute_error: 4.5091 - val_root_mean_squared_error: 5.6569 - val_mean_absolute_percentage_error: 22.5251 - val_mean_squared_error: 32.0006 - 5s/epoch - 533ms/step
# Epoch 112/2000
# 9/9 - 5s - loss: 9.5613 - mean_absolute_error: 2.4301 - root_mean_squared_error: 3.0921 - mean_absolute_percentage_error: 14.7174 - mean_squared_error: 9.5613 - val_loss: 32.8047 - val_mean_absolute_error: 4.5677 - val_root_mean_squared_error: 5.7275 - val_mean_absolute_percentage_error: 23.0981 - val_mean_squared_error: 32.8047 - 5s/epoch - 523ms/step
# Epoch 113/2000
# 9/9 - 5s - loss: 9.6345 - mean_absolute_error: 2.4166 - root_mean_squared_error: 3.1039 - mean_absolute_percentage_error: 14.4931 - mean_squared_error: 9.6345 - val_loss: 33.8752 - val_mean_absolute_error: 4.5816 - val_root_mean_squared_error: 5.8202 - val_mean_absolute_percentage_error: 23.0381 - val_mean_squared_error: 33.8752 - 5s/epoch - 518ms/step
# Epoch 114/2000
# 9/9 - 5s - loss: 9.6709 - mean_absolute_error: 2.4060 - root_mean_squared_error: 3.1098 - mean_absolute_percentage_error: 14.4760 - mean_squared_error: 9.6709 - val_loss: 32.1325 - val_mean_absolute_error: 4.4849 - val_root_mean_squared_error: 5.6686 - val_mean_absolute_percentage_error: 22.3176 - val_mean_squared_error: 32.1325 - 5s/epoch - 511ms/step
# Epoch 115/2000
# 9/9 - 5s - loss: 8.5592 - mean_absolute_error: 2.2969 - root_mean_squared_error: 2.9256 - mean_absolute_percentage_error: 13.9382 - mean_squared_error: 8.5592 - val_loss: 33.5831 - val_mean_absolute_error: 4.6784 - val_root_mean_squared_error: 5.7951 - val_mean_absolute_percentage_error: 23.1895 - val_mean_squared_error: 33.5831 - 5s/epoch - 525ms/step
# Epoch 116/2000
# 9/9 - 5s - loss: 8.7064 - mean_absolute_error: 2.2728 - root_mean_squared_error: 2.9507 - mean_absolute_percentage_error: 13.6705 - mean_squared_error: 8.7064 - val_loss: 34.4308 - val_mean_absolute_error: 4.6325 - val_root_mean_squared_error: 5.8678 - val_mean_absolute_percentage_error: 22.8398 - val_mean_squared_error: 34.4308 - 5s/epoch - 526ms/step
# Epoch 117/2000
# 9/9 - 5s - loss: 9.3020 - mean_absolute_error: 2.3638 - root_mean_squared_error: 3.0499 - mean_absolute_percentage_error: 14.0148 - mean_squared_error: 9.3020 - val_loss: 32.6503 - val_mean_absolute_error: 4.5331 - val_root_mean_squared_error: 5.7140 - val_mean_absolute_percentage_error: 23.2188 - val_mean_squared_error: 32.6503 - 5s/epoch - 527ms/step
# Epoch 118/2000
# 9/9 - 5s - loss: 8.4698 - mean_absolute_error: 2.2573 - root_mean_squared_error: 2.9103 - mean_absolute_percentage_error: 13.7153 - mean_squared_error: 8.4698 - val_loss: 33.3264 - val_mean_absolute_error: 4.5629 - val_root_mean_squared_error: 5.7729 - val_mean_absolute_percentage_error: 22.9473 - val_mean_squared_error: 33.3264 - 5s/epoch - 518ms/step
# Epoch 119/2000
# 9/9 - 5s - loss: 8.0666 - mean_absolute_error: 2.2111 - root_mean_squared_error: 2.8402 - mean_absolute_percentage_error: 13.3185 - mean_squared_error: 8.0666 - val_loss: 32.6011 - val_mean_absolute_error: 4.5033 - val_root_mean_squared_error: 5.7097 - val_mean_absolute_percentage_error: 22.2657 - val_mean_squared_error: 32.6011 - 5s/epoch - 518ms/step
# Epoch 120/2000
# 9/9 - 5s - loss: 7.5183 - mean_absolute_error: 2.1055 - root_mean_squared_error: 2.7419 - mean_absolute_percentage_error: 12.4993 - mean_squared_error: 7.5183 - val_loss: 34.0754 - val_mean_absolute_error: 4.6341 - val_root_mean_squared_error: 5.8374 - val_mean_absolute_percentage_error: 23.1602 - val_mean_squared_error: 34.0754 - 5s/epoch - 531ms/step
# Epoch 121/2000
# 9/9 - 5s - loss: 7.1827 - mean_absolute_error: 2.0607 - root_mean_squared_error: 2.6801 - mean_absolute_percentage_error: 12.3867 - mean_squared_error: 7.1827 - val_loss: 32.8557 - val_mean_absolute_error: 4.5403 - val_root_mean_squared_error: 5.7320 - val_mean_absolute_percentage_error: 22.8862 - val_mean_squared_error: 32.8557 - 5s/epoch - 525ms/step
# Epoch 122/2000
# 9/9 - 5s - loss: 6.5706 - mean_absolute_error: 1.9753 - root_mean_squared_error: 2.5633 - mean_absolute_percentage_error: 11.6228 - mean_squared_error: 6.5706 - val_loss: 34.8800 - val_mean_absolute_error: 4.6400 - val_root_mean_squared_error: 5.9059 - val_mean_absolute_percentage_error: 23.3879 - val_mean_squared_error: 34.8800 - 5s/epoch - 518ms/step
# Epoch 123/2000
# 9/9 - 5s - loss: 6.3172 - mean_absolute_error: 1.9257 - root_mean_squared_error: 2.5134 - mean_absolute_percentage_error: 11.4340 - mean_squared_error: 6.3172 - val_loss: 33.3450 - val_mean_absolute_error: 4.5440 - val_root_mean_squared_error: 5.7745 - val_mean_absolute_percentage_error: 22.9115 - val_mean_squared_error: 33.3450 - 5s/epoch - 518ms/step
# Epoch 124/2000
# 9/9 - 5s - loss: 6.8668 - mean_absolute_error: 2.0306 - root_mean_squared_error: 2.6205 - mean_absolute_percentage_error: 11.9896 - mean_squared_error: 6.8668 - val_loss: 35.3526 - val_mean_absolute_error: 4.7224 - val_root_mean_squared_error: 5.9458 - val_mean_absolute_percentage_error: 22.9778 - val_mean_squared_error: 35.3526 - 5s/epoch - 519ms/step
# Epoch 125/2000
# 9/9 - 5s - loss: 6.4809 - mean_absolute_error: 1.9695 - root_mean_squared_error: 2.5458 - mean_absolute_percentage_error: 11.5138 - mean_squared_error: 6.4809 - val_loss: 32.8998 - val_mean_absolute_error: 4.5643 - val_root_mean_squared_error: 5.7358 - val_mean_absolute_percentage_error: 23.1440 - val_mean_squared_error: 32.8998 - 5s/epoch - 516ms/step
# Epoch 126/2000
# 9/9 - 5s - loss: 6.1819 - mean_absolute_error: 1.9142 - root_mean_squared_error: 2.4864 - mean_absolute_percentage_error: 11.3816 - mean_squared_error: 6.1819 - val_loss: 34.3326 - val_mean_absolute_error: 4.6053 - val_root_mean_squared_error: 5.8594 - val_mean_absolute_percentage_error: 22.9097 - val_mean_squared_error: 34.3326 - 5s/epoch - 524ms/step
# Epoch 127/2000
# 9/9 - 5s - loss: 5.6879 - mean_absolute_error: 1.8257 - root_mean_squared_error: 2.3849 - mean_absolute_percentage_error: 10.8172 - mean_squared_error: 5.6879 - val_loss: 33.8173 - val_mean_absolute_error: 4.6094 - val_root_mean_squared_error: 5.8153 - val_mean_absolute_percentage_error: 23.0829 - val_mean_squared_error: 33.8173 - 5s/epoch - 523ms/step
# Epoch 128/2000
# 9/9 - 5s - loss: 5.4324 - mean_absolute_error: 1.8012 - root_mean_squared_error: 2.3308 - mean_absolute_percentage_error: 10.4851 - mean_squared_error: 5.4324 - val_loss: 33.0105 - val_mean_absolute_error: 4.5442 - val_root_mean_squared_error: 5.7455 - val_mean_absolute_percentage_error: 22.9962 - val_mean_squared_error: 33.0105 - 5s/epoch - 522ms/step
# Epoch 129/2000
# 9/9 - 5s - loss: 5.1444 - mean_absolute_error: 1.7640 - root_mean_squared_error: 2.2681 - mean_absolute_percentage_error: 10.4145 - mean_squared_error: 5.1444 - val_loss: 33.6431 - val_mean_absolute_error: 4.5484 - val_root_mean_squared_error: 5.8003 - val_mean_absolute_percentage_error: 23.4843 - val_mean_squared_error: 33.6431 - 5s/epoch - 529ms/step
# Epoch 130/2000
# 9/9 - 5s - loss: 5.0812 - mean_absolute_error: 1.7211 - root_mean_squared_error: 2.2541 - mean_absolute_percentage_error: 10.0869 - mean_squared_error: 5.0812 - val_loss: 33.7000 - val_mean_absolute_error: 4.5674 - val_root_mean_squared_error: 5.8052 - val_mean_absolute_percentage_error: 22.3760 - val_mean_squared_error: 33.7000 - 5s/epoch - 527ms/step
# Epoch 131/2000
# 9/9 - 5s - loss: 4.6755 - mean_absolute_error: 1.6372 - root_mean_squared_error: 2.1623 - mean_absolute_percentage_error: 9.5910 - mean_squared_error: 4.6755 - val_loss: 34.8501 - val_mean_absolute_error: 4.6898 - val_root_mean_squared_error: 5.9034 - val_mean_absolute_percentage_error: 22.9421 - val_mean_squared_error: 34.8501 - 5s/epoch - 526ms/step
# Epoch 132/2000
# 9/9 - 5s - loss: 5.1603 - mean_absolute_error: 1.7390 - root_mean_squared_error: 2.2716 - mean_absolute_percentage_error: 10.2284 - mean_squared_error: 5.1603 - val_loss: 34.6264 - val_mean_absolute_error: 4.6235 - val_root_mean_squared_error: 5.8844 - val_mean_absolute_percentage_error: 23.0860 - val_mean_squared_error: 34.6264 - 5s/epoch - 524ms/step
# Epoch 133/2000
# 9/9 - 5s - loss: 4.6247 - mean_absolute_error: 1.6684 - root_mean_squared_error: 2.1505 - mean_absolute_percentage_error: 9.8362 - mean_squared_error: 4.6247 - val_loss: 33.4390 - val_mean_absolute_error: 4.6188 - val_root_mean_squared_error: 5.7826 - val_mean_absolute_percentage_error: 23.3286 - val_mean_squared_error: 33.4390 - 5s/epoch - 522ms/step
# Epoch 134/2000
# 9/9 - 5s - loss: 4.7511 - mean_absolute_error: 1.6875 - root_mean_squared_error: 2.1797 - mean_absolute_percentage_error: 9.9938 - mean_squared_error: 4.7511 - val_loss: 36.3747 - val_mean_absolute_error: 4.7828 - val_root_mean_squared_error: 6.0311 - val_mean_absolute_percentage_error: 23.9670 - val_mean_squared_error: 36.3747 - 5s/epoch - 529ms/step
# Epoch 135/2000
# 9/9 - 5s - loss: 5.3260 - mean_absolute_error: 1.7533 - root_mean_squared_error: 2.3078 - mean_absolute_percentage_error: 10.3836 - mean_squared_error: 5.3260 - val_loss: 35.4213 - val_mean_absolute_error: 4.7351 - val_root_mean_squared_error: 5.9516 - val_mean_absolute_percentage_error: 23.6730 - val_mean_squared_error: 35.4213 - 5s/epoch - 517ms/step
# Epoch 136/2000
# 9/9 - 5s - loss: 5.0127 - mean_absolute_error: 1.7300 - root_mean_squared_error: 2.2389 - mean_absolute_percentage_error: 10.0739 - mean_squared_error: 5.0127 - val_loss: 37.0838 - val_mean_absolute_error: 4.8024 - val_root_mean_squared_error: 6.0896 - val_mean_absolute_percentage_error: 23.4357 - val_mean_squared_error: 37.0838 - 5s/epoch - 520ms/step
# Epoch 137/2000
# 9/9 - 5s - loss: 4.5275 - mean_absolute_error: 1.6651 - root_mean_squared_error: 2.1278 - mean_absolute_percentage_error: 9.8651 - mean_squared_error: 4.5275 - val_loss: 33.4108 - val_mean_absolute_error: 4.5766 - val_root_mean_squared_error: 5.7802 - val_mean_absolute_percentage_error: 23.0888 - val_mean_squared_error: 33.4108 - 5s/epoch - 542ms/step
# Epoch 138/2000
# 9/9 - 5s - loss: 4.1484 - mean_absolute_error: 1.5842 - root_mean_squared_error: 2.0368 - mean_absolute_percentage_error: 9.4480 - mean_squared_error: 4.1484 - val_loss: 34.5605 - val_mean_absolute_error: 4.5815 - val_root_mean_squared_error: 5.8788 - val_mean_absolute_percentage_error: 23.2159 - val_mean_squared_error: 34.5605 - 5s/epoch - 522ms/step
# Epoch 139/2000
# 9/9 - 5s - loss: 3.8701 - mean_absolute_error: 1.5278 - root_mean_squared_error: 1.9672 - mean_absolute_percentage_error: 9.0935 - mean_squared_error: 3.8701 - val_loss: 35.0077 - val_mean_absolute_error: 4.6700 - val_root_mean_squared_error: 5.9167 - val_mean_absolute_percentage_error: 24.1438 - val_mean_squared_error: 35.0077 - 5s/epoch - 532ms/step
# Epoch 140/2000
# 9/9 - 5s - loss: 3.5753 - mean_absolute_error: 1.4302 - root_mean_squared_error: 1.8909 - mean_absolute_percentage_error: 8.3026 - mean_squared_error: 3.5753 - val_loss: 34.2327 - val_mean_absolute_error: 4.5981 - val_root_mean_squared_error: 5.8509 - val_mean_absolute_percentage_error: 23.2038 - val_mean_squared_error: 34.2327 - 5s/epoch - 528ms/step
# Epoch 141/2000
# 9/9 - 5s - loss: 3.1035 - mean_absolute_error: 1.3587 - root_mean_squared_error: 1.7617 - mean_absolute_percentage_error: 7.8163 - mean_squared_error: 3.1035 - val_loss: 35.8551 - val_mean_absolute_error: 4.7090 - val_root_mean_squared_error: 5.9879 - val_mean_absolute_percentage_error: 23.4570 - val_mean_squared_error: 35.8551 - 5s/epoch - 521ms/step
# Epoch 142/2000
# 9/9 - 5s - loss: 3.3243 - mean_absolute_error: 1.4025 - root_mean_squared_error: 1.8233 - mean_absolute_percentage_error: 8.2408 - mean_squared_error: 3.3243 - val_loss: 34.7289 - val_mean_absolute_error: 4.6948 - val_root_mean_squared_error: 5.8931 - val_mean_absolute_percentage_error: 23.6621 - val_mean_squared_error: 34.7289 - 5s/epoch - 521ms/step
# Epoch 143/2000
# 9/9 - 5s - loss: 3.2822 - mean_absolute_error: 1.3696 - root_mean_squared_error: 1.8117 - mean_absolute_percentage_error: 7.8187 - mean_squared_error: 3.2822 - val_loss: 34.8381 - val_mean_absolute_error: 4.6572 - val_root_mean_squared_error: 5.9024 - val_mean_absolute_percentage_error: 23.5058 - val_mean_squared_error: 34.8381 - 5s/epoch - 515ms/step
# Epoch 144/2000
# 9/9 - 5s - loss: 3.0249 - mean_absolute_error: 1.3349 - root_mean_squared_error: 1.7392 - mean_absolute_percentage_error: 7.7740 - mean_squared_error: 3.0249 - val_loss: 34.9516 - val_mean_absolute_error: 4.6978 - val_root_mean_squared_error: 5.9120 - val_mean_absolute_percentage_error: 23.4525 - val_mean_squared_error: 34.9516 - 5s/epoch - 526ms/step
# Epoch 145/2000
# 9/9 - 5s - loss: 2.8256 - mean_absolute_error: 1.2827 - root_mean_squared_error: 1.6810 - mean_absolute_percentage_error: 7.4850 - mean_squared_error: 2.8256 - val_loss: 34.6958 - val_mean_absolute_error: 4.6639 - val_root_mean_squared_error: 5.8903 - val_mean_absolute_percentage_error: 23.5511 - val_mean_squared_error: 34.6958 - 5s/epoch - 527ms/step
# Epoch 146/2000
# 9/9 - 5s - loss: 3.0534 - mean_absolute_error: 1.3615 - root_mean_squared_error: 1.7474 - mean_absolute_percentage_error: 7.9418 - mean_squared_error: 3.0534 - val_loss: 34.3580 - val_mean_absolute_error: 4.6459 - val_root_mean_squared_error: 5.8616 - val_mean_absolute_percentage_error: 22.8782 - val_mean_squared_error: 34.3580 - 5s/epoch - 537ms/step
# Epoch 147/2000
# 9/9 - 5s - loss: 3.0118 - mean_absolute_error: 1.3458 - root_mean_squared_error: 1.7355 - mean_absolute_percentage_error: 7.8166 - mean_squared_error: 3.0118 - val_loss: 35.4209 - val_mean_absolute_error: 4.6692 - val_root_mean_squared_error: 5.9515 - val_mean_absolute_percentage_error: 23.2877 - val_mean_squared_error: 35.4209 - 5s/epoch - 524ms/step
# Epoch 148/2000
# 9/9 - 5s - loss: 3.1028 - mean_absolute_error: 1.3545 - root_mean_squared_error: 1.7615 - mean_absolute_percentage_error: 7.9079 - mean_squared_error: 3.1028 - val_loss: 35.6399 - val_mean_absolute_error: 4.7192 - val_root_mean_squared_error: 5.9699 - val_mean_absolute_percentage_error: 23.8582 - val_mean_squared_error: 35.6399 - 5s/epoch - 523ms/step
# Epoch 149/2000
# 9/9 - 5s - loss: 2.8879 - mean_absolute_error: 1.3116 - root_mean_squared_error: 1.6994 - mean_absolute_percentage_error: 7.7539 - mean_squared_error: 2.8879 - val_loss: 34.9918 - val_mean_absolute_error: 4.6770 - val_root_mean_squared_error: 5.9154 - val_mean_absolute_percentage_error: 23.3782 - val_mean_squared_error: 34.9918 - 5s/epoch - 521ms/step
# 11/11 [==============================] - 1s 59ms/step - loss: 27.1446 - mean_absolute_error: 4.1501 - root_mean_squared_error: 5.2100 - mean_absolute_percentage_error: 20.7957 - mean_squared_error: 27.1446

# %%
best_model.evaluate(X_train, y_train, return_dict=True)
# Out:
# 34/34 [==============================] - 2s 55ms/step - loss: 20.4749 - mean_absolute_error: 3.5396 - root_mean_squared_error: 4.5249 - mean_absolute_percentage_error: 22.2427 - mean_squared_error: 20.4749
# {'loss': 20.474891662597656,
#  'mean_absolute_error': 3.5395729541778564,
#  'mean_absolute_percentage_error': 22.242687225341797,
#  'mean_squared_error': 20.474891662597656,
#  'root_mean_squared_error': 4.524919033050537}

# %%
best_model.evaluate(X_val, y_val, return_dict=True)
# Out:
# 11/11 [==============================] - 1s 56ms/step - loss: 25.9396 - mean_absolute_error: 4.0876 - root_mean_squared_error: 5.0931 - mean_absolute_percentage_error: 20.5084 - mean_squared_error: 25.9396
# {'loss': 25.939586639404297,
#  'mean_absolute_error': 4.0875983238220215,
#  'mean_absolute_percentage_error': 20.508424758911133,
#  'mean_squared_error': 25.939586639404297,
#  'root_mean_squared_error': 5.09309196472168}

# %%
score
# Out:
# {'loss': 27.144554138183594,
#  'mean_absolute_error': 4.150126934051514,
#  'mean_absolute_percentage_error': 20.795665740966797,
#  'mean_squared_error': 27.144554138183594,
#  'root_mean_squared_error': 5.210043430328369}

# %%
print(hist.history.keys())
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'root_mean_squared_error', 'mean_absolute_percentage_error', 'mean_squared_error', 'val_loss', 'val_mean_absolute_error', 'val_root_mean_squared_error', 'val_mean_absolute_percentage_error', 'val_mean_squared_error'])

# %%
# "Loss"
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig("stacked_lstm_loss.png", dpi=300)
plt.show()

# %%
pd.DataFrame(hist.history).plot(figsize=(8,5))
plt.show()

# %%
dates = np.array(range(31, 366))
plt.plot(dates, y_test, label='Real value')
plt.plot(dates, y_pred, label='Forecasts')
plt.xlabel('Time', fontsize=12)
plt.ylabel('Sales', fontsize=12)
plt.legend()
plt.savefig("stacked_lstm_forecast.png", dpi=500)
plt.show()

# %%
from scipy import stats
stats.ttest_ind(y_pred, y_test)
# Out:
# Ttest_indResult(statistic=array([-1.2370563], dtype=float32), pvalue=array([0.2165009]))

# %%
best_model.save('stacked_lstm.h5')
