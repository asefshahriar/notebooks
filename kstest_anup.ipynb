# %%
import numpy as np
import pandas as pd
from scipy.stats import kstest, kurtosis, skew
from scipy import stats
import scipy

# %%
data = pd.read_excel("/content/new-12.xlsx")

# %%
data.head()
# Out:
#    year  Resilience
# 0  2010        7.50
# 1  2011       51.25
# 2  2012       58.75
# 3  2013       88.00
# 4  2014      168.75

# %%
data.describe()
# Out:
#              year  Resilience
# count    10.00000   10.000000
# mean   2014.50000  134.825000
# std       3.02765   78.700386
# min    2010.00000    7.500000
# 25%    2012.25000   66.062500
# 50%    2014.50000  162.750000
# 75%    2016.75000  178.937500
# max    2019.00000  244.000000

# %%
kurtosis(data["Resilience"])
# Out:
# -1.2052206528233589

# %%
skew(data["Resilience"])
# Out:
# -0.24770318458576898

# %%
# drawing sample from the fitted distribution
rvs1 = stats.logistic.rvs(loc=138.34, scale=45.404, random_state=0, size=10000)

# %%
kurtosis(rvs1)
# Out:
# 1.4598363647829222

# %%
skew(rvs1)
# Out:
# -0.030074992822692152

# %%
rvs1.mean()
# Out:
# 137.08054999813484

# %%
scipy.stats.ks_2samp(data["Resilience"],rvs1 )
# Out:
# Ks_2sampResult(statistic=0.2058, pvalue=0.7192326932131585)
